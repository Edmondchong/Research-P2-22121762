# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers datasets peft wandb sacremoses
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.19.1)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.5.1+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft) (1.2.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.25.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.10.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.19.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 20.5 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 50.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.5 MB/s eta 0:00:00
# Installing collected packages: xxhash, sacremoses, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 sacremoses-0.1.1 xxhash-3.5.0

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
from peft import LoraConfig, get_peft_model
import pandas as pd
from sklearn.model_selection import train_test_split
import torch

# %%
# Check GPU availability
if torch.cuda.is_available():
    print("GPU is available!")
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available. Please enable it in runtime settings.")
# Out:
# GPU is available!
# GPU name: NVIDIA A100-SXM4-40GB

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # Load Dataset

# %%
# File paths
training_set = "/content/drive/MyDrive/P2/T1/Dataset/non_overlapped/LLM-no-train.csv"
validation_set = "/content/drive/MyDrive/P2/T1/Dataset/non_overlapped/LLM-no-val.csv"
testing_set = "/content/drive/MyDrive/P2/T1/Dataset/non_overlapped/LLM-no-test.csv"
# Load datasets
train_data = pd.read_csv(training_set)
val_data = pd.read_csv(validation_set)
test_data = pd.read_csv(testing_set)

# Add prompt column to the datasets
for dataset in [train_data, val_data, test_data]:
    dataset['prompt'] = dataset.apply(
        lambda row: f"Symptoms: {row['symptoms']}\nPredict the disease:",
        axis=1
    )

# Create mappings for text-based labels
unique_labels = train_data['disease_label'].unique()
label_to_id = {label: idx for idx, label in enumerate(unique_labels)}
id_to_label = {idx: label for idx, label in enumerate(unique_labels)}

# Map text labels to numeric indices
for dataset in [train_data, val_data, test_data]:
    dataset['target'] = dataset['disease_label'].map(label_to_id)

# Convert to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_data)
val_dataset = Dataset.from_pandas(val_data)
test_dataset = Dataset.from_pandas(test_data)

print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of validation samples: {len(val_dataset)}")
print(f"Number of testing samples: {len(test_dataset)}")

disease_counts = train_data['disease_label'].value_counts()
print("Disease Distribution in Training Data:")
print(disease_counts)
# Out:
# Number of training samples: 37384
# Number of validation samples: 7974
# Number of testing samples: 7974
# Disease Distribution in Training Data:
# disease_label
# infection urinary tract               762
# fibroid tumor                         761
# carcinoma breast                      758
# hyperglycemia                         757
# ulcer peptic                          757
# cirrhosis                             757
# schizophrenia                         756
# effusion pericardial                  753
# deep vein thrombosis                  751
# adhesion                              751
# obesity                               751
# obesity morbid                        749
# neutropenia                           749
# epilepsy                              747
# overload fluid                        746
# adenocarcinoma                        746
# hepatitis                             746
# dependence                            746
# tachycardia sinus                     745
# manic disorder                        744
# gastritis                             743
# delirium                              740
# infection                             733
# osteomyelitis                         731
# degenerative polyarthritis            710
# paroxysmal dyspnea                    710
# hypoglycemia                          710
# hepatitis C                           707
# colitis                               703
# peripheral vascular disease           700
# sickle cell anemia                    698
# thrombus                              697
# gastroenteritis                       692
# biliary calculus                      683
# stenosis aortic valve                 682
# malignant neoplasms                   681
# failure heart                         672
# hyperlipidemia                        672
# hypertensive disease                  666
# neuropathy                            582
# neoplasm metastasis                   580
# arthritis                             577
# kidney failure acute                  577
# glaucoma                              576
# gout                                  567
# tricuspid valve insufficiency         561
# chronic obstructive airway disease    556
# pyelonephritis                        532
# coronary arteriosclerosis             497
# hepatitis B                           355
# affect labile                         353
# benign prostatic hypertrophy          352
# pneumothorax                          350
# hypertension pulmonary                350
# hyperbilirubinemia                    350
# thrombocytopaenia                     348
# asthma                                337
# melanoma                              336
# pancreatitis                          286
# Name: count, dtype: int64

# %% [markdown]
# # Load LLM

# %%
# Import the required classes
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Load ClinicalBERT model and tokenizer
model_name = "emilyalsentzer/Bio_ClinicalBERT"  # ClinicalBERT model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=len(unique_labels)
)

print("ClinicalBERT model and tokenizer loaded successfully!")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at emilyalsentzer/Bio_ClinicalBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ClinicalBERT model and tokenizer loaded successfully!

# %% [markdown]
# # LoRA (Low-Rank Adaptation)

# %%
# Configure LoRA for BioBERT
lora_config = LoraConfig(
    r=8,  # Low-rank adaptation rank
    lora_alpha=32,  # Scaling factor
    target_modules=["query", "value"],  # LoRA applied to attention layers
    lora_dropout=0.1,  # Dropout rate for regularization
    task_type="SEQ_CLS"  # Sequence classification task
)

model = get_peft_model(model, lora_config)
print("LoRA applied successfully to ClinicalBERT!")
# Out:
# LoRA applied successfully to ClinicalBERT!

# %% [markdown]
# # Tokenization function

# %%
# Tokenization function for the dataset
def tokenize_function(examples):
    # Tokenize the 'prompt' column
    tokenized_inputs = tokenizer(
        examples['prompt'],  # Input text (symptoms prompt)
        truncation=True,
        padding='max_length',
        max_length=256,  # Adjust as needed
        return_tensors="pt"
    )
    # Add 'labels' field (numeric targets)
    tokenized_inputs["labels"] = examples["target"]
    return tokenized_inputs

# Apply tokenization to the datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Set the dataset format for PyTorch
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
val_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/37384 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7974 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7974 [00:00<?, ? examples/s]

# %% [markdown]
# # Training Arguments

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir='./results_clinicalbert',
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    learning_rate=5e-5,
    num_train_epochs=6,
    weight_decay=0.005,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    logging_dir='./logs_clinicalbert',
    logging_steps=10,
    fp16=True,  # Mixed precision
    load_best_model_at_end=True,
    metric_for_best_model='eval_loss',
    greater_is_better=False
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer
)
# Out:
# <ipython-input-11-fe264dbe4e1a>:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# Train the model
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20241225_152253-wttky5lg</code>
# Syncing run <strong><a href='https://wandb.ai/edmondchongyh-universiti-malaya-students-union/huggingface/runs/wttky5lg' target="_blank">./results_clinicalbert</a></strong> to <a href='https://wandb.ai/edmondchongyh-universiti-malaya-students-union/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/edmondchongyh-universiti-malaya-students-union/huggingface' target="_blank">https://wandb.ai/edmondchongyh-universiti-malaya-students-union/huggingface</a>
#  View run at <a href='https://wandb.ai/edmondchongyh-universiti-malaya-students-union/huggingface/runs/wttky5lg' target="_blank">https://wandb.ai/edmondchongyh-universiti-malaya-students-union/huggingface/runs/wttky5lg</a>
#     <div>
#
#       <progress value='14022' max='14022' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14022/14022 13:17, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.953000</td>
#       <td>1.854771</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.956800</td>
#       <td>0.893767</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.511100</td>
#       <td>0.548845</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.351400</td>
#       <td>0.304499</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.310800</td>
#       <td>0.234088</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.316500</td>
#       <td>0.209110</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=14022, training_loss=1.0757182808137284, metrics={'train_runtime': 821.8936, 'train_samples_per_second': 272.911, 'train_steps_per_second': 17.061, 'total_flos': 2.9640770928820224e+16, 'train_loss': 1.0757182808137284, 'epoch': 6.0})

# %% [markdown]
# # Training and Validation Loss Graph

# %%
"""
import matplotlib.pyplot as plt

# Data from the table
epochs = [1, 2]
training_loss = [2.1982, 2.4477, 1.8128, 1.3208, 1.1841, 1.1038]
validation_loss = [1.836972, 2.2917, 1.5439, 1.1537, 0.9580, 0.9067]

# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(epochs, training_loss, label="Training Loss", marker="o")
plt.plot(epochs, validation_loss, label="Validation Loss", marker="o")

# Add labels, title, and legend
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Epochs")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
"""
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Data from the table\nepochs = [1, 2]\ntraining_loss = [2.1982, 2.4477, 1.8128, 1.3208, 1.1841, 1.1038]\nvalidation_loss = [1.836972, 2.2917, 1.5439, 1.1537, 0.9580, 0.9067]\n\n# Plot the graph\nplt.figure(figsize=(10, 6))\nplt.plot(epochs, training_loss, label="Training Loss", marker="o")\nplt.plot(epochs, validation_loss, label="Validation Loss", marker="o")\n\n# Add labels, title, and legend\nplt.xlabel("Epoch")\nplt.ylabel("Loss")\nplt.title("Training and Validation Loss Over Epochs")\nplt.legend()\nplt.grid(True)\n\n# Show the plot\nplt.show()\n'

# %%
"""
model.save_pretrained('/content/drive/MyDrive/P2/LLM/fine_tuned_biobert')
tokenizer.save_pretrained('/content/drive/MyDrive/P2/LLM/fine_tuned_biobert')
print("Fine-tuned BioBERT model and tokenizer saved successfully!")
"""
# Out:
# '\nmodel.save_pretrained(\'/content/drive/MyDrive/P2/LLM/fine_tuned_biobert\')\ntokenizer.save_pretrained(\'/content/drive/MyDrive/P2/LLM/fine_tuned_biobert\')\nprint("Fine-tuned BioBERT model and tokenizer saved successfully!")\n'

# %% [markdown]
# # Evaluate the fine-tuned model directly

# %%
from datasets import Dataset

# Load the test dataset
test_file_path = '/content/drive/MyDrive/P2/T1/Dataset/non_overlapped/LLM-no-test.csv'
test_data = pd.read_csv(test_file_path)

# Add prompt column (if not already present)
test_data['prompt'] = test_data.apply(
    lambda row: f"Symptoms: {row['symptoms']}\nPredict the disease:",
    axis=1
)

# Convert to Hugging Face Dataset
test_dataset = Dataset.from_pandas(test_data)

# %%
import re

def predict_disease(prompt):
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=256).to("cuda")
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predicted_class_id = torch.argmax(logits, dim=-1).item()
        return id_to_label[predicted_class_id]  # Map numeric index back to text label

# Test Predictions
test_data['predicted_disease'] = test_data['prompt'].apply(predict_disease)

# Print Predictions
for index, row in test_data.iterrows():
    print(f"Prompt: {row['prompt']}")
    print(f"Predicted Disease: {row['predicted_disease']}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have sore to touch.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have sore to touch; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have sore to touch; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have sore to touch; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have nausea; have diarrhea.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have sore to touch; have vomiting; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have nausea; have sore to touch; have vomiting; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have sore to touch; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have sore to touch; have vomiting; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have vomiting; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have nausea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have nausea; have sore to touch; have vomiting; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have vomiting; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have nausea; have sore to touch; have vomiting.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have sore to touch; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have nausea; have vomiting; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have sore to touch; have vomiting; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have sore to touch; have vomiting; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have sore to touch; have vomiting; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have vomiting; have diarrhea.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have sore to touch; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have vomiting; have diarrhea.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have nausea; have vomiting; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have nausea.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have nausea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nausea; have vomiting; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have nausea; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have sore to touch; have vomiting; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have sore to touch; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have vomiting; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have nausea; have sore to touch; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have nausea; have vomiting; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have sore to touch; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have nausea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have vomiting; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have sore to touch; have diarrhea.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have nausea; have vomiting; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have sore to touch.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have sore to touch; have vomiting; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have vomiting; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nausea; have sore to touch; have vomiting; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have apyrexial; have nausea; have vomiting; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have diarrhea.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have sore to touch; have diarrhea; have rigor - temperature-associated observation; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have rale; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have jugular venous distention; have sweat; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have sweat; have orthopnea; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have rale; have orthopnea; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have pain chest; have sweat; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have dyspnea on exertion; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have rale; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have rale; have sweat; have orthopnea; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have sweat; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have rale; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have rale; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have cough.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have jugular venous distention; have dyspnea on exertion; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have rale; have sweat; have dyspnea on exertion; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have pain chest; have sweat; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have dyspnea; have jugular venous distention; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have sweat; have orthopnea; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have rale; have sweat; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have rale; have orthopnea; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have jugular venous distention; have pain chest; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have rale; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have orthopnea; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have orthopnea; have dyspnea on exertion; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have rale; have sweat; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have pain chest; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have sweat; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have sweat; have orthopnea; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have jugular venous distention; have pain chest; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have orthopnea; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have orthopnea; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have pain chest; have rale; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have sweat; have orthopnea; have dyspnea on exertion; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have rale; have sweat; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have orthopnea; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have cough.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have rale; have sweat; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have pain chest; have rale; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweat; have orthopnea; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have pain chest; have sweat; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sweat; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have pain chest; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have rale; have orthopnea; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have rale; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have pain chest; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have rale; have sweat; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have pain chest; have rale; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have orthopnea; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have rale; have sweat; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have cough.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have rale; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have dyspnea on exertion; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have orthopnea; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sweat; have dyspnea on exertion; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have rale; have sweat; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have sweat; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have sweat; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have pain chest; have rale; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have rale; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have jugular venous distention; have rale; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have orthopnea; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have rale; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have pain chest; have orthopnea; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have rale; have sweat; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have sweat; have orthopnea; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have orthopnea; have sweating increased; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have dyspnea on exertion; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have orthopnea; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have sweat; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have pain chest; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have dyspnea on exertion; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have pain chest; have rale; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have rale; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have dyspnea on exertion; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have dyspnea on exertion; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have rale; have sweat; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have jugular venous distention.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have dyspnea; have rale; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have rale; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have rale; have dyspnea on exertion; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sweating increased; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have rale; have orthopnea; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have jugular venous distention; have dyspnea on exertion; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have jugular venous distention; have rale; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have pain chest; have rale; have orthopnea; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have rale; have dyspnea on exertion; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have pain chest; have rale; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have rale; have sweat; have dyspnea on exertion; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have pain chest; have sweat; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweating increased; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea on exertion; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have pain chest; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have jugular venous distention; have pain chest; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have weight gain.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have sweat; have orthopnea; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have sweat; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweat; have dyspnea on exertion; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have pain chest; have sweat; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have orthopnea; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have orthopnea; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have jugular venous distention; have pain chest; have rale; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have jugular venous distention; have pain chest; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have jugular venous distention; have weight gain.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have rale; have sweat; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have dyspnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have sweat; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have rale; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have orthopnea; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have rale; have sweat; have orthopnea; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have pain chest; have sweat; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have orthopnea; have dyspnea on exertion; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have rale; have orthopnea; have sweating increased; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have rale; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have dyspnea; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have pain chest; have cough.
# Predict the disease:
# Predicted Disease: asthma
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have dyspnea on exertion; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have rale; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have pain chest; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have dyspnea; have rale; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have pain chest; have rale; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have sweat; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have rale.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have rale; have sweat; have dyspnea on exertion; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have jugular venous distention; have dyspnea on exertion; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have rale; have sweat; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have pain chest; have rale; have orthopnea.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have orthopnea; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have rale; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea on exertion; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have pain chest; have sweat; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have rale; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have pain chest; have rale; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have rale; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dyspnea; have sweat; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have rale; have sweat; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have pain chest; have sweat; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sweat; have orthopnea; have sweating increased; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have rale; have sweat; have orthopnea; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have rale; have orthopnea; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have rest pain; have labored breathing; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have hyperkalemia; have angina pectoris; have anorexia; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have hyperkalemia; have rest pain; have anorexia; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have hyperkalemia; have angina pectoris; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have anorexia; have labored breathing; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sinus rhythm; have sore to touch; have hyperkalemia; have angina pectoris.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have sinus rhythm; have sore to touch; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have angina pectoris; have rest pain; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have hyperkalemia; have angina pectoris; have rest pain; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have sore to touch; have labored breathing.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have sinus rhythm; have sore to touch; have angina pectoris; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have hyperkalemia; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have sinus rhythm; have angina pectoris; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have sinus rhythm; have hyperkalemia; have anorexia; have labored breathing; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have hyperkalemia; have anorexia; have labored breathing; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have sinus rhythm; have angina pectoris; have rest pain; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sinus rhythm; have hyperkalemia; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have sinus rhythm; have sore to touch; have rest pain; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have dyspnea; have sinus rhythm; have angina pectoris; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have angina pectoris; have rest pain; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have unresponsiveness; have dyspnea; have sore to touch; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have hyperkalemia; have rest pain.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have sinus rhythm; have rest pain; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have hyperkalemia; have angina pectoris; have anorexia; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have unresponsiveness; have dyspnea; have hyperkalemia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have unresponsiveness; have angina pectoris; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have sinus rhythm; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have hyperkalemia; have rest pain; have anorexia; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have sinus rhythm; have angina pectoris; have anorexia; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have sinus rhythm; have sore to touch; have hyperkalemia; have angina pectoris; have sleepy.
# Predict the disease:
# ...
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have out of breath; have nervousness.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have pain chest; have nausea; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have vomiting; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nervousness; have hunger; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have nervousness; have apyrexial; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have nervousness; have apyrexial; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have pain chest; have apyrexial; have vomiting; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have apyrexial; have nausea; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nervousness; have apyrexial; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nausea; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have nervousness; have nausea; have hunger.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have nervousness; have apyrexial; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have vomiting.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nervousness; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have out of breath; have hunger; have hemiplegia; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have pain chest; have nausea; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nervousness; have apyrexial; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have hunger; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nausea; have hunger; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have nausea; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have out of breath; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have nervousness; have hunger; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nausea; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have vomiting; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain chest; have out of breath; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nausea; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nervousness; have apyrexial; have nausea; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have out of breath; have apyrexial; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have out of breath; have apyrexial; have nausea; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have nervousness; have apyrexial; have nausea; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have pain chest; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain chest; have out of breath; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nausea; have hunger.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have pain chest; have out of breath; have nervousness; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have nervousness; have apyrexial; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nervousness; have vomiting; have hemiplegia; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have nausea; have vomiting; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nervousness; have apyrexial; have vomiting; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have vomiting; have hunger; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have pain chest; have hunger; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have out of breath; have nervousness; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have pain chest; have vomiting; have hunger; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nervousness.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nervousness; have apyrexial; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have vomiting; have hunger; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have nervousness; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have pain chest; have nervousness; have nausea; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have out of breath; have nausea; have hunger; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have out of breath; have nausea.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have out of breath; have nausea; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have out of breath; have nausea; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have apyrexial; have hunger; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nervousness; have hunger; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain chest; have out of breath; have nervousness; have nausea.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have apyrexial; have nausea; have vomiting; have hunger.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have vomiting; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have hunger; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have apyrexial; have vomiting; have hunger.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nervousness; have apyrexial; have nausea; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have out of breath; have nervousness; have hunger; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nervousness; have vomiting; have hunger; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nervousness; have vomiting; have hunger; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have hemiplegia; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have nervousness; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nervousness; have apyrexial; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nausea; have vomiting; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nervousness; have nausea; have vomiting; have hunger; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain chest; have out of breath; have apyrexial; have hunger.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have apyrexial; have hemiplegia; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have apyrexial; have nausea; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have hunger; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have pain chest; have out of breath; have vomiting; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have apyrexial; have hemiplegia; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have hemiplegia; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have out of breath.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have nervousness; have nausea; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have out of breath; have nausea.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have out of breath; have nervousness; have vomiting; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain chest; have apyrexial; have nausea.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have out of breath; have nervousness; have nausea.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nervousness; have apyrexial; have vomiting; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have nervousness; have apyrexial; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have out of breath; have nervousness; have vomiting; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have hunger; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic

# %% [markdown]
# # Save fine-tuned Model

# %%
"""
# Save the fine-tuned model
model.save_pretrained('/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt')
tokenizer.save_pretrained('/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt')
print("Fine-tuned BioGPT model and tokenizer saved successfully!")
"""
# Out:
# '\n# Save the fine-tuned model\nmodel.save_pretrained(\'/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt\')\ntokenizer.save_pretrained(\'/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt\')\nprint("Fine-tuned BioGPT model and tokenizer saved successfully!")\n'

# %% [markdown]
# # Generate Classification Report

# %%
from sklearn.metrics import classification_report
import pandas as pd

# Assume `test_data` is your test dataset after generating predictions
# The test_data dataframe should already have columns: 'Label' (true labels) and 'Predicted' (model predictions)

# True labels and predicted labels
true_labels = test_data['disease_label']
predicted_labels = test_data['predicted_disease']

# Generate classification report
report = classification_report(true_labels, predicted_labels, output_dict=False)
print(report)

# Save classification report to a file
report_dict = classification_report(true_labels, predicted_labels, output_dict=True)
pd.DataFrame(report_dict).transpose().to_csv('/content/drive/MyDrive/P2/T1/Dataset/non_overlapped/LLM/ClinicalBERT-no-class.csv', index=True)
print("Classification report saved to '/content/drive/MyDrive/P2/T1/Dataset/non_overlapped/LLM/ClinicalBERT-no-class.csv'")
# Out:
#                                     precision    recall  f1-score   support
#
#                     adenocarcinoma       0.98      0.99      0.98       159
#                           adhesion       0.97      0.92      0.95       160
#                      affect labile       0.97      0.91      0.94        75
#                          arthritis       0.98      0.95      0.97       123
#                             asthma       0.97      0.94      0.96        71
#       benign prostatic hypertrophy       0.96      0.93      0.95        75
#                   biliary calculus       0.94      0.92      0.93       146
#                   carcinoma breast       0.98      0.98      0.98       162
# chronic obstructive airway disease       0.95      0.98      0.97       119
#                          cirrhosis       0.86      0.99      0.92       162
#                            colitis       0.92      1.00      0.96       150
#          coronary arteriosclerosis       0.93      0.89      0.91       106
#               deep vein thrombosis       0.99      0.99      0.99       160
#         degenerative polyarthritis       1.00      0.98      0.99       151
#                           delirium       0.94      0.96      0.95       158
#                         dependence       0.99      0.96      0.97       159
#               effusion pericardial       0.96      0.98      0.97       161
#                           epilepsy       0.97      1.00      0.98       160
#                      failure heart       0.92      0.99      0.95       143
#                      fibroid tumor       1.00      0.98      0.99       163
#                          gastritis       0.97      0.93      0.95       159
#                    gastroenteritis       0.99      0.99      0.99       148
#                           glaucoma       1.00      0.95      0.97       123
#                               gout       0.96      0.98      0.97       121
#                          hepatitis       0.97      0.93      0.95       159
#                        hepatitis B       0.92      0.95      0.93        75
#                        hepatitis C       0.97      0.99      0.98       151
#                 hyperbilirubinemia       1.00      0.87      0.93        75
#                      hyperglycemia       0.99      0.96      0.97       161
#                     hyperlipidemia       0.98      0.91      0.94       143
#             hypertension pulmonary       0.97      0.88      0.92        75
#               hypertensive disease       0.82      0.87      0.84       142
#                       hypoglycemia       0.99      0.98      0.99       152
#                          infection       0.93      1.00      0.96       156
#            infection urinary tract       0.97      0.99      0.98       163
#               kidney failure acute       0.93      0.98      0.96       123
#               malignant neoplasms        0.97      0.92      0.95       145
#                     manic disorder       0.90      0.99      0.94       159
#                           melanoma       0.98      0.88      0.93        72
#                neoplasm metastasis       0.99      0.96      0.98       124
#                         neuropathy       0.98      0.98      0.98       124
#                        neutropenia       0.99      0.89      0.94       160
#                            obesity       0.99      1.00      1.00       160
#                     obesity morbid       0.94      0.98      0.96       160
#                      osteomyelitis       0.99      0.99      0.99       156
#                     overload fluid       0.99      0.96      0.97       159
#                       pancreatitis       1.00      0.93      0.97        60
#                 paroxysmal dyspnea       0.99      0.91      0.95       152
#        peripheral vascular disease       0.94      0.98      0.96       150
#                       pneumothorax       0.99      0.91      0.94        74
#                     pyelonephritis       0.94      1.00      0.97       113
#                      schizophrenia       1.00      0.99      0.99       161
#                 sickle cell anemia       0.99      1.00      1.00       149
#              stenosis aortic valve       0.86      0.99      0.92       146
#                  tachycardia sinus       0.99      0.94      0.96       159
#                  thrombocytopaenia       1.00      0.99      0.99        74
#                           thrombus       0.99      0.95      0.97       148
#      tricuspid valve insufficiency       0.94      0.99      0.96       119
#                       ulcer peptic       0.98      0.99      0.98       161
#
#                           accuracy                           0.96      7974
#                          macro avg       0.96      0.96      0.96      7974
#                       weighted avg       0.96      0.96      0.96      7974
#
# Classification report saved to '/content/drive/MyDrive/P2/T1/Dataset/non_overlapped/LLM/ClinicalBERT-no-class.csv'

# %%
"""
output_path = '/content/drive/MyDrive/P2/LLM/ClinicalBERT_Predictions.csv'
test_data.to_csv(output_path, index=False)
print(f"Predictions saved to: {output_path}")
"""
# Out:
# '\noutput_path = \'/content/drive/MyDrive/P2/LLM/ClinicalBERT_Predictions.csv\'\ntest_data.to_csv(output_path, index=False)\nprint(f"Predictions saved to: {output_path}")\n'
