# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers datasets peft wandb sacremoses
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.19.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.5.1+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft) (1.2.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.25.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.10.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.19.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from peft import LoraConfig, get_peft_model

# %%
# Check GPU availability
if torch.cuda.is_available():
    print("GPU is available!")
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available. Please enable it in runtime settings.")
# Out:
# GPU is available!
# GPU name: NVIDIA A100-SXM4-40GB

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # Load Dataset

# %%
# File paths
training_set = "/content/drive/MyDrive/P2/T1/Dataset/combined/LLM-c-train.csv"
validation_set = "/content/drive/MyDrive/P2/T1/Dataset/combined/LLM-c-val.csv"
testing_set = "/content/drive/MyDrive/P2/T1/Dataset/combined/LLM-c-test.csv"

# Load datasets
train_data = pd.read_csv(training_set)
val_data = pd.read_csv(validation_set)
test_data = pd.read_csv(testing_set)

# Add prompt column to the datasets
for dataset in [train_data, val_data, test_data]:
    dataset['prompt'] = dataset.apply(
        lambda row: f"Symptoms: {row['symptoms']}\nPredict the disease:",
        axis=1
    )

# Create mappings for text-based labels
unique_labels = train_data['disease_label'].unique()
label_to_id = {label: idx for idx, label in enumerate(unique_labels)}
id_to_label = {idx: label for idx, label in enumerate(unique_labels)}

# Map text labels to numeric indices
for dataset in [train_data, val_data, test_data]:
    dataset['target'] = dataset['disease_label'].map(label_to_id)

# Convert to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_data)
val_dataset = Dataset.from_pandas(val_data)
test_dataset = Dataset.from_pandas(test_data)

print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of validation samples: {len(val_dataset)}")
print(f"Number of testing samples: {len(test_dataset)}")

disease_counts = train_data['disease_label'].value_counts()
print("Disease Distribution in Training Data:")
print(disease_counts)
# Out:
# Number of training samples: 50944
# Number of validation samples: 9646
# Number of testing samples: 9718
# Disease Distribution in Training Data:
# disease_label
# hypertensive disease                  1530
# biliary calculus                      1491
# hyperlipidemia                        1464
# coronary arteriosclerosis             1385
# colitis                               1303
# paroxysmal dyspnea                    1270
# failure heart                         1120
# osteomyelitis                         1115
# infection                             1093
# pyelonephritis                        1068
# malignant neoplasms                   1033
# gastritis                             1007
# stenosis aortic valve                  994
# overload fluid                         978
# delirium                               964
# hepatitis                              962
# pancreatitis                           958
# deep vein thrombosis                   943
# manic disorder                         936
# dependence                             930
# tachycardia sinus                      929
# adenocarcinoma                         922
# effusion pericardial                   921
# epilepsy                               915
# gastroenteritis                        900
# chronic obstructive airway disease     900
# schizophrenia                          900
# thrombus                               889
# tricuspid valve insufficiency          889
# adhesion                               887
# obesity                                887
# neutropenia                            885
# obesity morbid                         885
# hyperglycemia                          885
# sickle cell anemia                     882
# carcinoma breast                       870
# cirrhosis                              861
# peripheral vascular disease            844
# infection urinary tract                834
# gout                                   815
# fibroid tumor                          761
# ulcer peptic                           757
# arthritis                              737
# kidney failure acute                   713
# glaucoma                               712
# hypoglycemia                           710
# degenerative polyarthritis             710
# hepatitis C                            707
# neuropathy                             582
# neoplasm metastasis                    580
# asthma                                 545
# melanoma                               544
# pneumothorax                           430
# benign prostatic hypertrophy           408
# affect labile                          401
# hepatitis B                            355
# hypertension pulmonary                 350
# hyperbilirubinemia                     350
# thrombocytopaenia                      348
# Name: count, dtype: int64

# %%
disease_counts = train_data['disease_label'].value_counts()
print("Disease Distribution in Training Data:")
print(disease_counts)
# Out:
# Disease Distribution in Training Data:
# disease_label
# hypertensive disease                  1530
# biliary calculus                      1491
# hyperlipidemia                        1464
# coronary arteriosclerosis             1385
# colitis                               1303
# paroxysmal dyspnea                    1270
# failure heart                         1120
# osteomyelitis                         1115
# infection                             1093
# pyelonephritis                        1068
# malignant neoplasms                   1033
# gastritis                             1007
# stenosis aortic valve                  994
# overload fluid                         978
# delirium                               964
# hepatitis                              962
# pancreatitis                           958
# deep vein thrombosis                   943
# manic disorder                         936
# dependence                             930
# tachycardia sinus                      929
# adenocarcinoma                         922
# effusion pericardial                   921
# epilepsy                               915
# gastroenteritis                        900
# chronic obstructive airway disease     900
# schizophrenia                          900
# thrombus                               889
# tricuspid valve insufficiency          889
# adhesion                               887
# obesity                                887
# neutropenia                            885
# obesity morbid                         885
# hyperglycemia                          885
# sickle cell anemia                     882
# carcinoma breast                       870
# cirrhosis                              861
# peripheral vascular disease            844
# infection urinary tract                834
# gout                                   815
# fibroid tumor                          761
# ulcer peptic                           757
# arthritis                              737
# kidney failure acute                   713
# glaucoma                               712
# hypoglycemia                           710
# degenerative polyarthritis             710
# hepatitis C                            707
# neuropathy                             582
# neoplasm metastasis                    580
# asthma                                 545
# melanoma                               544
# pneumothorax                           430
# benign prostatic hypertrophy           408
# affect labile                          401
# hepatitis B                            355
# hypertension pulmonary                 350
# hyperbilirubinemia                     350
# thrombocytopaenia                      348
# Name: count, dtype: int64

# %% [markdown]
# # Load LLM

# %%
# Import the required classes
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Load BioBERT
model_name = "dmis-lab/biobert-base-cased-v1.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=59)  # Placeholder for `num_labels`

# GPU Check
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # LoRA (Low-Rank Adaptation)

# %%
# Configure LoRA for BioBERT
lora_config = LoraConfig(
    r=16,  # Low-rank adaptation rank
    lora_alpha=32,  # Scaling factor
    target_modules=["query", "value"],  # LoRA applied to attention layers
    lora_dropout=0.1,  # Dropout rate for regularization
    task_type="SEQ_CLS"  # Sequence classification task
)

model = get_peft_model(model, lora_config)
print("LoRA applied successfully to BioBERT!")
# Out:
# LoRA applied successfully to BioBERT!

# %% [markdown]
# # Tokenization function

# %%
# Tokenization function for the dataset
def tokenize_function(examples):
    # Tokenize the 'prompt' column
    tokenized_inputs = tokenizer(
        examples['prompt'],  # Input text (symptoms prompt)
        truncation=True,
        padding='max_length',
        max_length=256,  # Adjust as needed
        return_tensors="pt"
    )
    # Add 'labels' field (numeric targets)
    tokenized_inputs["labels"] = examples["target"]
    return tokenized_inputs

# Apply tokenization to the datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Set the dataset format for PyTorch
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
val_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/50944 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9646 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9718 [00:00<?, ? examples/s]

# %% [markdown]
# # Training Arguments

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    logging_strategy="steps",
    logging_steps=10,
    learning_rate=5e-5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs = 6,
    weight_decay=0.001,
    logging_dir="./logs",
    save_strategy="epoch",
    save_total_limit=2,
    remove_unused_columns=False  # Disable column filtering
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset= val_dataset,
    tokenizer=tokenizer
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-42-f41fd194d000>:20: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset= val_dataset,
    tokenizer=tokenizer
)
# Out:
# <ipython-input-43-d09d09b8867b>:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# Train the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='9552' max='9552' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9552/9552 38:17, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.163500</td>
#       <td>1.971682</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.411600</td>
#       <td>1.213706</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.095400</td>
#       <td>0.849066</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.966100</td>
#       <td>0.673803</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.888400</td>
#       <td>0.596718</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.888700</td>
#       <td>0.572131</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9552, training_loss=1.4626299418771087, metrics={'train_runtime': 2297.4417, 'train_samples_per_second': 133.045, 'train_steps_per_second': 4.158, 'total_flos': 4.053059239359283e+16, 'train_loss': 1.4626299418771087, 'epoch': 6.0})

# %% [markdown]
# # Training and Validation Loss Graph

# %%
"""
import matplotlib.pyplot as plt

# Data from the table
epochs = [1, 2, 3, 4, 5, 6]
training_loss = [2.616900, 1.970200, 1.714200, 1.640900, 1.364900, 1.114800]
validation_loss = [2.713036, 1.945025, 1.528872, 1.351326, 1.194266, 1.159532]

# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(epochs, training_loss, label="Training Loss", marker="o")
plt.plot(epochs, validation_loss, label="Validation Loss", marker="o")

# Add labels, title, and legend
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Epochs")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
"""
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Data from the table\nepochs = [1, 2, 3, 4, 5, 6]\ntraining_loss = [2.616900, 1.970200, 1.714200, 1.640900, 1.364900, 1.114800]\nvalidation_loss = [2.713036, 1.945025, 1.528872, 1.351326, 1.194266, 1.159532]\n\n# Plot the graph\nplt.figure(figsize=(10, 6))\nplt.plot(epochs, training_loss, label="Training Loss", marker="o")\nplt.plot(epochs, validation_loss, label="Validation Loss", marker="o")\n\n# Add labels, title, and legend\nplt.xlabel("Epoch")\nplt.ylabel("Loss")\nplt.title("Training and Validation Loss Over Epochs")\nplt.legend()\nplt.grid(True)\n\n# Show the plot\nplt.show()\n'

# %% [markdown]
# # Evaluate the fine-tuned model directly

# %%
from datasets import Dataset

# Load the test dataset
test_file_path = '/content/drive/MyDrive/P2/T1/Dataset/combined/LLM-c-test.csv'
test_data = pd.read_csv(test_file_path)

# Add prompt column (if not already present)
test_data['prompt'] = test_data.apply(
    lambda row: f"Symptoms: {row['symptoms']}\nPredict the disease:",
    axis=1
)

# Convert to Hugging Face Dataset
test_dataset = Dataset.from_pandas(test_data)

# %%
import re

def predict_disease(prompt):
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=256).to("cuda")
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predicted_class_id = torch.argmax(logits, dim=-1).item()
        return id_to_label[predicted_class_id]  # Map numeric index back to text label

# Test Predictions
test_data['predicted_disease'] = test_data['prompt'].apply(predict_disease)

# Print Predictions
for index, row in test_data.iterrows():
    print(f"Prompt: {row['prompt']}")
    print(f"Predicted Disease: {row['predicted_disease']}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have stiffness; have polydypsia; have numbness of hand.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have unconscious state; have clammy skin; have claudication; have qt interval prolonged.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have nausea; have cushingoid habitus; have diarrhea.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have nervousness; have apyrexial; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have yellow sputum; have inappropriate affect; have abdominal tenderness; have wheelchair bound; have poor feeding.
# Predict the disease:
# Predicted Disease: hepatitis B
# Prompt: Symptoms: Patient shows symptoms as follows: have hemodynamically stable; have fever; have hematuria; have consciousness clear.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have oliguria; have distress respiratory; have cough.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have agitation; have homelessness; have stuffy nose.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have vomiting.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have aura; have hypometabolism; have drowsiness.
# Predict the disease:
# Predicted Disease: epilepsy
# Prompt: Symptoms: Patient shows symptoms as follows: have unsteady gait; have feeling suicidal.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have headache; have breakthrough pain; have pain chest; have apyrexial; have pain back.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have cushingoid facies; have para 1.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have ecchymosis; have fatigue; have r wave feature; have tired.
# Predict the disease:
# Predicted Disease: obesity
# Prompt: Symptoms: Patient shows symptoms as follows: have decompensation; have energy increased; have difficulty; have feeling suicidal.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have hematochezia; have cicatrisation; have fremitus.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have angina pectoris; have syncope.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweat; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have nausea; have chill; have pain.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have cardiovascular finding; have hypercapnia; have agitation; have dyspnea; have cardiovascular event; have haemoptysis; have cough.
# Predict the disease:
# Predicted Disease: pneumothorax
# Prompt: Symptoms: Patient shows symptoms as follows: have hydropneumothorax; have fatigability.
# Predict the disease:
# Predicted Disease: neuropathy
# Prompt: Symptoms: Patient shows symptoms as follows: have primigravida; have abortion; have hypotonic.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have cushingoid facies; have ascites; have cushingoid habitus.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have hypercapnia; have sputum purulent; have patient non compliance; have hypoxemia; have distress respiratory; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have immobile; have breech presentation; have unsteady gait.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have cushingoid facies; have cushingoid habitus; have cyanosis; have para 1; have bradycardia; have myalgia.
# Predict the disease:
# Predicted Disease: hyperbilirubinemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have intermenstrual heavy bleeding; have haemorrhage; have para 2.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have hematuria; have nausea; have chill; have myalgia.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have giddy mood; have dizziness; have sweat.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have hemodynamically stable; have diarrhea; have oliguria.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have diarrhea; have chill; have pain; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have intoxication; have pericardial friction rub; have oliguria; have blackout.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have asterixis; have ache; have macerated skin; have chill; have feeling suicidal.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have sedentary; have renal angle tenderness; have cough.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have dyspnea on exertion; have sciatica; have syncope; have pain.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have angina pectoris; have dyspnea on exertion; have sweating increased.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have hemodynamically stable; have haemorrhage; have hyperkalemia; have diarrhea; have hypocalcemia result; have oliguria.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have cushingoid facies; have hematuria; have ascites; have pain.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have transaminitis; have monoclonal; have oliguria.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have chest discomfort; have pain.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have hematuria; have nausea; have urgency of micturition; have myalgia; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have dizziness; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have homelessness; have seizure.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have ecchymosis; have tired; have overweight; have snore.
# Predict the disease:
# Predicted Disease: obesity
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have left atrial hypertrophy; have sweat.
# Predict the disease:
# Predicted Disease: tachycardia sinus
# Prompt: Symptoms: Patient shows symptoms as follows: have tremor; have myoclonus; have drowsiness; have hemiplegia.
# Predict the disease:
# Predicted Disease: epilepsy
# Prompt: Symptoms: Patient shows symptoms as follows: have systolic murmur; have bradycardia.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokalemia; have hyperkalemia.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have frothy sputum; have angina pectoris; have systolic murmur.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have orthopnea; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have wheezing; have chest tightness; have non-productive cough; have productive cough.
# Predict the disease:
# Predicted Disease: asthma
# Prompt: Symptoms: Patient shows symptoms as follows: have hypercapnia; have shortness of breath; have hypoxemia.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have nausea; have vomiting; have chill.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have heme positive; have pain abdominal; have vomiting; have disequilibrium; have guaiac positive.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have dizziness; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have vomiting; have anorexia.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have blanch; have feeling hopeless; have decompensation.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have ascites.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have inappropriate affect; have tachypnea.
# Predict the disease:
# Predicted Disease: hepatitis B
# Prompt: Symptoms: Patient shows symptoms as follows: have vomiting; have diarrhea; have paraparesis; have pain.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have pruritus; have ascites; have anorexia; have chill.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have tremor; have lethargy; have suicidal.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have apyrexial; have thicken; have ascites.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have fatigue; have dyspnea; have pansystolic murmur; have hypotension.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have ascites; have pain.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have decreased translucency; have chill; have hepatosplenomegaly; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have asthenia; have slowing of urinary stream; have nausea and vomiting; have tenesmus; have pain.
# Predict the disease:
# Predicted Disease: neuropathy
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have angina pectoris; have rest pain; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have hypotension.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sweat; have orthopnea.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have nausea; have sore to touch; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have cushingoid facies; have thicken; have hoarseness; have pain.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have sore to touch; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have urinary hesitation; have apyrexial; have sore to touch; have erythema; have pain.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have orthopnea; have blackout.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have cardiomegaly; have hypotension; have pericardial friction rub; have oliguria.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have immobile; have lung nodule; have flatulence.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have orthopnea; have cough; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have wheezing; have chest tightness; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have wheezing; have chest tightness; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have rale; have sweat; have orthopnea; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have worry.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sleeplessness; have general unsteadiness; have distended abdomen.
# Predict the disease:
# Predicted Disease: arthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have dizziness; have fall; have syncope.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling hopeless; have hallucinations visual.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have nausea.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have fever; have diarrhea; have hallucinations auditory.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have mental status changes; have orthostasis; have orthopnea; have night sweat; have dysarthria; have anorexia; have cachexia; have distress respiratory.
# Predict the disease:
# Predicted Disease: benign prostatic hypertrophy
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sleeplessness; have asthenia; have pain.
# Predict the disease:
# Predicted Disease: arthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have night sweat; have hypocalcemia result; have monoclonal.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have lameness; have incoherent; have clammy skin; have hypotension; have polyuria.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have apyrexial; have vomiting; have hunger.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have lameness; have hypothermia, natural; have unresponsiveness; have qt interval prolonged; have polyuria.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have sweat; have dyspnea on exertion; have sweating increased.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have orthopnea; have angina pectoris; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have worry.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have claudication; have qt interval prolonged; have hypotension; have polyuria.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have atypia; have thicken; have tumor cell invasion; have lung nodule; have pain.
# Predict the disease:
# Predicted Disease: neoplasm metastasis
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have vomiting; have anorexia.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have night sweat; have dysarthria; have cachexia.
# Predict the disease:
# Predicted Disease: benign prostatic hypertrophy
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have hematuria; have hoarseness; have pain.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have pain abdominal; have food intolerance; have metastatic lesion; have lung nodule; have pain.
# Predict the disease:
# Predicted Disease: neoplasm metastasis
# Prompt: Symptoms: Patient shows symptoms as follows: have giddy mood; have sweat; have angina pectoris; have hemiplegia.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have hematuria; have nausea; have urgency of micturition; have myalgia; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have fatigue; have r wave feature.
# Predict the disease:
# Predicted Disease: obesity
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have apyrexial; have hepatosplenomegaly; have pain; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have worry; have homelessness; have patient non compliance; have suicidal; have underweight.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have emphysematous change; have pain; have hot flush.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have headache; have pain abdominal; have green sputum; have pain back; have pain.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have asthenia; have sweating increased; have vertigo.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have chest discomfort; have angina pectoris; have sweating increased; have presence of q wave.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have breech presentation; have vomiting.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have burning sensation; have estrogen use.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have jugular venous distention; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have abscess bacterial.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have angina pectoris; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have vomiting; have green sputum; have tenesmus.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have non-productive cough; have nonsmoker; have food intolerance; have drowsiness; have pain.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have hemodynamically stable; have fever; have hematuria; have renal angle tenderness.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have chest discomfort; have dyspnea on exertion; have syncope.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have pain abdominal; have thicken; have pain.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have haemorrhage; have heartburn; have hypotonic; have muscle hypotonia.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have urinary hesitation; have abscess bacterial; have apyrexial; have erythema.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have blackout.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain abdominal; have cicatrisation; have nausea; have pain.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have decreased body weight; have pruritus; have seizure.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have decreased body weight; have ascites; have pustule.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have vomiting; have flatulence.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have fever; have hypotonic; have para 2.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have hematuria; have nausea; have vomiting.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have scar tissue; have pain abdominal; have cardiovascular event.
# Predict the disease:
# Predicted Disease: tachycardia sinus
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling hopeless; have bedridden.1; have extreme exhaustion.
# Predict the disease:
# Predicted Disease: affect labile
# Prompt: Symptoms: Patient shows symptoms as follows: have diarrhea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have large-for-dates fetus; have breech presentation; have unsteady gait; have pain.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have sputum purulent; have cardiomegaly; have oliguria.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have lesion; have hemodynamically stable; have splenomegaly; have bleeding of vagina.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have chest tightness; have orthopnea; have angina pectoris.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have unconscious state; have distended abdomen.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have tremor; have intoxication; have rale; have homelessness.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sinus rhythm; have sore to touch; have hyperkalemia; have rest pain.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have chest tightness; have productive cough; have distress respiratory; have pleuritic pain; have cough.
# Predict the disease:
# Predicted Disease: asthma
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have dizziness; have haemorrhage.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have chill.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have sciatica.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have worry.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have mental status changes; have anorexia; have cachexia; have blackout.
# Predict the disease:
# Predicted Disease: benign prostatic hypertrophy
# Prompt: Symptoms: Patient shows symptoms as follows: have heme positive; have decreased body weight; have haemorrhage; have vomiting.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have hyperkalemia; have anorexia; have labored breathing; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have lethargy; have asthenia; have renal angle tenderness.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have blanch; have energy increased; have verbal auditory hallucinations.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have suicidal; have diarrhea; have unsteady gait; have feeling suicidal.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have rale; have orthopnea; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have hemodynamically stable; have splenomegaly; have distended abdomen.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have worry; have drowsiness; have unsteady gait; have sleepy.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have hyponatremia; have retch; have scleral icterus; have sore to touch.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have feeling strange; have decreased body weight; have cushingoid habitus; have estrogen use.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have asthenia; have hemodynamically stable; have hyperkalemia; have hypocalcemia result.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have hyponatremia; have retch; have fever; have nausea; have sore to touch.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have ascites; have pain.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have mediastinal shift; have nausea; have bradycardia.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have orthopnea; have hypotension.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have ascites; have emphysematous change.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have general discomfort; have non-productive cough; have food intolerance; have unsteady gait.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling hopeless; have bedridden; have patient non compliance.
# Predict the disease:
# Predicted Disease: affect labile
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have mediastinal shift; have nausea; have vomiting; have impaired cognition; have bradycardia.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have pruritus; have diarrhea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have sweat; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have incoherent; have unresponsiveness; have clammy skin; have claudication.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have apyrexial; have pruritus.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have splenomegaly; have sore to touch; have fall.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have intoxication; have decreased body weight; have nausea; have sore to touch; have pain.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have nausea; have sore to touch; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have atypia; have mass of body structure; have pain neck; have thicken; have metastatic lesion; have lung nodule.
# Predict the disease:
# Predicted Disease: neoplasm metastasis
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have diarrhea; have drowsiness; have unsteady gait.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have rale; have drowsiness.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have pain abdominal; have scleral icterus.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have orthostasis; have dysarthria; have cachexia.
# Predict the disease:
# Predicted Disease: benign prostatic hypertrophy
# Prompt: Symptoms: Patient shows symptoms as follows: have breech presentation; have vomiting; have unsteady gait; have pain.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have t wave inverted; have vomiting; have sweating increased; have pressure chest.
# Predict the disease:
# Predicted Disease: tachycardia sinus
# Prompt: Symptoms: Patient shows symptoms as follows: have general discomfort; have asthenia; have polydypsia; have food intolerance; have unsteady gait.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have diarrhea; have drowsiness.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sweat; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have difficulty.
# Predict the disease:
# Predicted Disease: affect labile
# Prompt: Symptoms: Patient shows symptoms as follows: have asthenia; have numbness; have slowing of urinary stream; have nausea and vomiting; have tenesmus; have pain.
# Predict the disease:
# Predicted Disease: neuropathy
# Prompt: Symptoms: Patient shows symptoms as follows: have wheelchair bound; have drowsiness.
# Predict the disease:
# Predicted Disease: epilepsy
# Prompt: Symptoms: Patient shows symptoms as follows: have abscess bacterial; have sore to touch; have prostate tender.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have agitation; have lesion; have hyponatremia; have burning sensation.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have night sweat; have oliguria; have rhd positive.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have sore to touch; have vomiting; have diarrhea.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have cushingoid facies; have sore to touch; have ascites.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have cushingoid facies; have pain.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have diarrhea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have cushingoid facies; have sore to touch; have ascites.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have cushingoid facies; have apyrexial; have cushingoid habitus; have pain.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have clonus; have erythema; have pain in lower limb; have pain.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have cardiomegaly; have hemodynamically stable; have pain.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have hallucinations auditory; have macerated skin; have feeling suicidal; have cough.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have sore to touch.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have awakening early; have hemodynamically stable; have vomiting; have urge incontinence.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have energy increased.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have immobile; have breech presentation; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have vomiting; have unsteady gait.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have redness; have sore to touch; have pain.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have lameness; have hypothermia, natural; have unresponsiveness; have claudication; have distress respiratory.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have fever; have cicatrisation; have nausea; have vomiting; have bradycardia.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sore to touch; have pruritus; have anorexia; have hypoalbuminemia.
# Predict the disease:
# Predicted Disease: thrombus
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have chill.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have urge incontinence; have nausea and vomiting; have pain.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have wheezing; have chest tightness; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have atypia; have mass of body structure; have food intolerance; have tumor cell invasion; have metastatic lesion; have pain.
# Predict the disease:
# Predicted Disease: neoplasm metastasis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have hypokinesia; have sweat; have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have pain foot; have urinary hesitation; have abscess bacterial; have sore to touch; have difficulty passing urine.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have ascites; have hoarseness; have emphysematous change.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have immobile; have breech presentation; have feeling suicidal; have pain.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have lethargy; have hyponatremia; have mental status changes; have consciousness clear.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have abscess bacterial; have fever; have apyrexial.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have jugular venous distention; have rale; have hyperkalemia.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have claudication; have hypotension; have distress respiratory.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have wheezing; have chest tightness; have dyspnea; have hypoxemia; have distress respiratory.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have nausea; have bradycardia.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have green sputum; have nausea and vomiting; have chill.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have left atrial hypertrophy; have alcohol binge episode; have vomiting; have pressure chest.
# Predict the disease:
# Predicted Disease: tachycardia sinus
# Prompt: Symptoms: Patient shows symptoms as follows: have agitation; have lethargy; have suicidal; have stuffy nose.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have chest tightness; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweat; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have general discomfort; have non-productive cough; have food intolerance.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have urgency of micturition; have vomiting; have myalgia.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have immobile; have feeling suicidal.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have ascites; have hallucinations auditory; have macerated skin.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have hypotension; have distress respiratory.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have hypercapnia; have prostatism; have agitation; have cardiovascular event.
# Predict the disease:
# Predicted Disease: pneumothorax
# Prompt: Symptoms: Patient shows symptoms as follows: have tremor; have lethargy; have drowsiness.
# Predict the disease:
# Predicted Disease: epilepsy
# Prompt: Symptoms: Patient shows symptoms as follows: have rale; have homelessness; have stuffy nose.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have facial paresis.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have nervousness; have apyrexial; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have apyrexial; have hemiplegia; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have sore to touch.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have hematuria; have cushingoid habitus; have emphysematous change.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have headache; have breakthrough pain; have pain back.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have vomiting; have hunger; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have agitation; have homelessness; have suicidal; have irritable mood.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have constipation; have decreased body weight; have hematochezia; have cicatrisation.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have egophony.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweat; have dyspnea on exertion; have sweating increased.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have hypoxemia; have labored breathing.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have splenomegaly; have sore to touch; have ascites.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have haemorrhage; have abnormally hard consistency; have previous pregnancies 2; have para 2.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have pruritus; have ascites; have estrogen use.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have lameness; have clammy skin; have qt interval prolonged; have hypotension; have distress respiratory.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have pruritus; have chill; have hepatosplenomegaly; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have worry; have hyponatremia; have diarrhea; have feeling suicidal.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have syncope; have pain.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have redness; have rale; have non-productive cough; have clonus; have pain in lower limb.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have fever; have withdraw.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have giddy mood; have presence of q wave.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# ...
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have hypokalemia; have orthopnea; have hypotension; have weight gain.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have hypoxemia; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have immobile; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have abdominal tenderness; have projectile vomiting; have wheelchair bound; have poor feeding.
# Predict the disease:
# Predicted Disease: hepatitis B
# Prompt: Symptoms: Patient shows symptoms as follows: have asthenia; have numbness; have slowing of urinary stream; have nausea and vomiting; have superimposition; have pain.
# Predict the disease:
# Predicted Disease: neuropathy
# Prompt: Symptoms: Patient shows symptoms as follows: have homelessness; have suicidal; have verbal auditory hallucinations; have hallucinations visual; have hypersomnolence.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have hematuria; have diarrhea; have chill; have myalgia; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have abscess bacterial; have decreased translucency; have chill.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have unconscious state; have agitation; have distended abdomen; have burning sensation; have unsteady gait.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have agitation; have distended abdomen; have paresthesia.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have monocytosis; have ecchymosis; have fever; have haemorrhage; have pruritus; have tachypnea.
# Predict the disease:
# Predicted Disease: thrombocytopaenia
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have hematuria; have urgency of micturition; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have hypotension; have weight gain.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have blanch; have decompensation; have elation; have verbally abusive behavior.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have urinary hesitation; have abscess bacterial; have apyrexial; have sore to touch; have prostate tender.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have lethargy; have hyponatremia; have dysuria; have asthenia; have difficulty passing urine.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have pain foot; have abscess bacterial; have pain.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have cardiomegaly; have hypotension.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have cicatrisation; have nausea; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have hematocrit decreased; have dyspnea; have angina pectoris.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have hypokinesia; have sweat; have angina pectoris.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have fatigue; have jugular venous distention; have hypokinesia; have systolic ejection murmur; have pansystolic murmur.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling strange; have mood depressed; have sore to touch; have pustule; have seizure.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have blanch; have feeling hopeless; have decompensation; have hallucinations auditory.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have swelling; have orthopnea; have hypotension; have drowsiness.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have prostatism; have feeling hopeless; have stuffy nose.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have orthopnea; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have green sputum; have chill; have pain.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have r wave feature; have systolic murmur; have catatonia.
# Predict the disease:
# Predicted Disease: obesity
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have intoxication; have hemodynamically stable; have pain.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have vomiting; have diarrhea.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have chest tightness; have pain chest; have hypokinesia; have sweat; have orthopnea.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have rale; have sweat; have sweating increased.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have hypokinesia; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have pain neck; have thicken; have food intolerance; have metastatic lesion.
# Predict the disease:
# Predicted Disease: neoplasm metastasis
# Prompt: Symptoms: Patient shows symptoms as follows: have breech presentation; have cushingoid habitus; have bradycardia; have cough.
# Predict the disease:
# Predicted Disease: hyperbilirubinemia
# Prompt: Symptoms: Patient shows symptoms as follows: have abscess bacterial; have diarrhea; have chill; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have mediastinal shift; have fever; have cicatrisation; have nausea; have bradycardia; have pain.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have thicken; have food intolerance; have pain.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have difficulty; have estrogen use; have formication; have mass in breast.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have r wave feature; have mood depressed; have tired; have has religious belief.
# Predict the disease:
# Predicted Disease: obesity
# Prompt: Symptoms: Patient shows symptoms as follows: have cardiovascular finding; have hypercapnia; have prostatism; have agitation; have dyspnea; have cardiovascular event; have haemoptysis; have soft tissue swelling.
# Predict the disease:
# Predicted Disease: pneumothorax
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have headache; have breakthrough pain; have apyrexial; have green sputum.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have heavy feeling; have asterixis; have distended abdomen; have ascites; have ache.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have breakthrough pain; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have sputum purulent; have pericardial friction rub; have pain; have blackout.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have general discomfort; have stiffness; have nonsmoker; have drowsiness.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have syncope; have pain.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have hematocrit decreased; have unhappy; have angina pectoris; have feels hot/feverish.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have constipation; have lesion; have satiety early; have egophony.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have decreased body weight; have dizziness; have haemorrhage; have vomiting.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have hemodynamically stable; have pain.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypercapnia; have wheezing; have chest tightness; have dyspnea; have hypoxemia; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have cardiovascular finding; have scar tissue; have sweat; have sweating increased.
# Predict the disease:
# Predicted Disease: tachycardia sinus
# Prompt: Symptoms: Patient shows symptoms as follows: have sputum purulent; have wheezing; have dyspnea; have hypoxemia; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have breech presentation; have vomiting; have feeling suicidal.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have pain foot; have abscess bacterial; have fever; have sore to touch.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have erythema; have estrogen use; have formication.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have monocytosis; have fever; have haemorrhage; have hypotension; have tachypnea.
# Predict the disease:
# Predicted Disease: thrombocytopaenia
# Prompt: Symptoms: Patient shows symptoms as follows: have worry; have homelessness; have underweight; have underweight.1; have hypersomnolence.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have lethargy; have hyponatremia; have fever; have hematuria.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have cardiomegaly; have erythema; have pain in lower limb.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have heme positive; have intoxication; have decreased body weight; have dizziness; have nausea.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have lethargy; have hyponatremia; have asthenia; have consciousness clear; have difficulty passing urine.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have hypokinesia; have ascites; have erythema; have emphysematous change.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have asterixis; have patient non compliance; have macerated skin.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have thicken; have vomiting; have ascites; have cushingoid habitus.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have vomiting; have diarrhea; have paraparesis; have mass in breast; have pain.
# Predict the disease:
# Predicted Disease: melanoma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have sore to touch.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have unresponsiveness; have sinus rhythm; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling strange; have sore to touch; have pruritus; have pustule.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have intermenstrual heavy bleeding; have fever; have hypotonic.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have diarrhea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have hepatosplenomegaly; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have hypokinesia; have giddy mood; have chest discomfort.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have anorexia; have distress respiratory; have tachypnea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have heavy feeling; have hallucinations auditory; have chill.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have night sweat; have monoclonal; have cough.
# Predict the disease:
# Predicted Disease: neutropenia

# %% [markdown]
# # Save fine-tuned Model

# %%
"""
# Save the fine-tuned model
model.save_pretrained('/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt')
tokenizer.save_pretrained('/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt')
print("Fine-tuned BioGPT model and tokenizer saved successfully!")
"""
# Out:
# '\n# Save the fine-tuned model\nmodel.save_pretrained(\'/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt\')\ntokenizer.save_pretrained(\'/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt\')\nprint("Fine-tuned BioGPT model and tokenizer saved successfully!")\n'

# %% [markdown]
# # Generate Classification Report

# %%
from sklearn.metrics import classification_report
import pandas as pd

# Assume `test_data` is your test dataset after generating predictions
# The test_data dataframe should already have columns: 'Label' (true labels) and 'Predicted' (model predictions)

# True labels and predicted labels
true_labels = test_data['disease_label']
predicted_labels = test_data['predicted_disease']

# Generate classification report
report = classification_report(true_labels, predicted_labels, output_dict=False)
print(report)

# Save classification report to a file
report_dict = classification_report(true_labels, predicted_labels, output_dict=True)
pd.DataFrame(report_dict).transpose().to_csv('/content/drive/MyDrive/P2/T1/Dataset/combined/LLM/BioBERT-c-class.csv', index=True)
print("Classification report saved to '/content/drive/MyDrive/P2/T1/Dataset/combined/LLM/BioBERT-c-class.csv'")
# Out:
#                                     precision    recall  f1-score   support
#
#                     adenocarcinoma       0.83      0.95      0.88       183
#                           adhesion       0.96      0.85      0.90       176
#                      affect labile       0.79      0.84      0.81        83
#                          arthritis       0.96      0.82      0.88       139
#                             asthma       0.87      0.80      0.84        95
#       benign prostatic hypertrophy       0.98      0.71      0.83        83
#                   biliary calculus       0.90      0.65      0.76       242
#                   carcinoma breast       0.94      0.94      0.94       178
# chronic obstructive airway disease       0.68      0.95      0.79       159
#                          cirrhosis       0.93      0.84      0.88       194
#                            colitis       0.63      0.88      0.74       206
#          coronary arteriosclerosis       0.71      0.68      0.70       218
#               deep vein thrombosis       0.94      0.90      0.92       176
#         degenerative polyarthritis       0.93      0.99      0.96       151
#                           delirium       0.80      0.84      0.82       198
#                         dependence       0.82      0.91      0.86       175
#               effusion pericardial       0.90      0.98      0.94       177
#                           epilepsy       0.78      0.95      0.86       184
#                      failure heart       0.82      0.91      0.86       183
#                      fibroid tumor       0.95      0.92      0.93       163
#                          gastritis       0.97      0.83      0.89       183
#                    gastroenteritis       0.99      0.73      0.84       180
#                           glaucoma       0.97      0.81      0.89       139
#                               gout       0.88      0.88      0.88       153
#                          hepatitis       0.67      0.77      0.71       207
#                        hepatitis B       0.98      0.87      0.92        75
#                        hepatitis C       1.00      0.97      0.99       151
#                 hyperbilirubinemia       0.99      0.89      0.94        75
#                      hyperglycemia       0.85      0.92      0.89       185
#                     hyperlipidemia       0.74      0.58      0.65       287
#             hypertension pulmonary       1.00      0.88      0.94        75
#               hypertensive disease       0.55      0.87      0.67       278
#                       hypoglycemia       0.95      0.93      0.94       152
#                          infection       0.83      0.88      0.85       196
#            infection urinary tract       0.95      0.95      0.95       171
#               kidney failure acute       0.90      0.82      0.86       155
#               malignant neoplasms        0.88      0.82      0.85       177
#                     manic disorder       0.88      0.95      0.91       183
#                           melanoma       0.98      0.61      0.76        88
#                neoplasm metastasis       0.99      0.94      0.97       124
#                         neuropathy       1.00      0.94      0.97       124
#                        neutropenia       0.93      0.82      0.87       192
#                            obesity       0.97      0.92      0.95       168
#                     obesity morbid       0.94      0.73      0.82       184
#                      osteomyelitis       0.87      0.94      0.90       188
#                     overload fluid       0.80      0.87      0.83       183
#                       pancreatitis       0.58      0.76      0.66       140
#                 paroxysmal dyspnea       0.92      0.64      0.75       240
#        peripheral vascular disease       0.84      0.90      0.87       166
#                       pneumothorax       1.00      0.63      0.78        90
#                     pyelonephritis       0.63      0.78      0.69       201
#                      schizophrenia       0.94      0.90      0.92       177
#                 sickle cell anemia       0.98      0.94      0.96       157
#              stenosis aortic valve       0.83      0.96      0.89       178
#                  tachycardia sinus       0.99      0.80      0.89       183
#                  thrombocytopaenia       0.97      0.91      0.94        74
#                           thrombus       0.98      0.84      0.91       172
#      tricuspid valve insufficiency       0.82      0.89      0.85       143
#                       ulcer peptic       0.96      0.97      0.96       161
#
#                           accuracy                           0.85      9718
#                          macro avg       0.88      0.85      0.86      9718
#                       weighted avg       0.87      0.85      0.85      9718
#
# Classification report saved to '/content/drive/MyDrive/P2/T1/Dataset/combined/LLM/BioBERT-c-class.csv'

# %%
"""
output_path = '/content/drive/MyDrive/P2/LLM/2BioBERT_Predictions.csv'
test_data.to_csv(output_path, index=False)
print(f"Predictions saved to: {output_path}")
"""
# Out:
# '\noutput_path = \'/content/drive/MyDrive/P2/LLM/2BioBERT_Predictions.csv\'\ntest_data.to_csv(output_path, index=False)\nprint(f"Predictions saved to: {output_path}")\n'
