# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers datasets peft wandb sacremoses
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.4)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.5.1+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft) (1.2.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.25.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.10.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.20.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 10.4 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 39.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, sacremoses, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 sacremoses-0.1.1 xxhash-3.5.0

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from peft import LoraConfig, get_peft_model

# %%
# Check GPU availability
if torch.cuda.is_available():
    print("GPU is available!")
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available. Please enable it in runtime settings.")
# Out:
# GPU is available!
# GPU name: NVIDIA A100-SXM4-40GB

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # Load Dataset

# %%
# File paths
training_set = "/content/drive/MyDrive/P2/T1/Dataset/combined/LLM-c-train.csv"
validation_set = "/content/drive/MyDrive/P2/T1/Dataset/combined/LLM-c-val.csv"
testing_set = "/content/drive/MyDrive/P2/T1/Dataset/combined/LLM-c-test.csv"

# Load datasets
train_data = pd.read_csv(training_set)
val_data = pd.read_csv(validation_set)
test_data = pd.read_csv(testing_set)

# Add prompt column to the datasets
for dataset in [train_data, val_data, test_data]:
    dataset['prompt'] = dataset.apply(
        lambda row: f"Symptoms: {row['symptoms']}\nPredict the disease:",
        axis=1
    )

# Create mappings for text-based labels
unique_labels = train_data['disease_label'].unique()
label_to_id = {label: idx for idx, label in enumerate(unique_labels)}
id_to_label = {idx: label for idx, label in enumerate(unique_labels)}

# Map text labels to numeric indices
for dataset in [train_data, val_data, test_data]:
    dataset['target'] = dataset['disease_label'].map(label_to_id)

# Convert to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_data)
val_dataset = Dataset.from_pandas(val_data)
test_dataset = Dataset.from_pandas(test_data)

print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of validation samples: {len(val_dataset)}")
print(f"Number of testing samples: {len(test_dataset)}")

disease_counts = train_data['disease_label'].value_counts()
print("Disease Distribution in Training Data:")
print(disease_counts)
# Out:
# Number of training samples: 44164
# Number of validation samples: 8810
# Number of testing samples: 8846
# Disease Distribution in Training Data:
# disease_label
# hypertensive disease                  1098
# biliary calculus                      1087
# hyperlipidemia                        1068
# colitis                               1003
# paroxysmal dyspnea                     990
# coronary arteriosclerosis              941
# osteomyelitis                          923
# infection                              913
# failure heart                          896
# gastritis                              875
# overload fluid                         862
# malignant neoplasms                    857
# hepatitis                              854
# delirium                               852
# deep vein thrombosis                   847
# manic disorder                         840
# dependence                             838
# stenosis aortic valve                  838
# effusion pericardial                   837
# tachycardia sinus                      837
# adenocarcinoma                         834
# epilepsy                               831
# schizophrenia                          828
# hyperglycemia                          821
# adhesion                               819
# obesity                                819
# obesity morbid                         817
# neutropenia                            817
# carcinoma breast                       814
# cirrhosis                              809
# pyelonephritis                         800
# infection urinary tract                798
# gastroenteritis                        796
# thrombus                               793
# sickle cell anemia                     790
# peripheral vascular disease            772
# fibroid tumor                          761
# ulcer peptic                           757
# chronic obstructive airway disease     728
# tricuspid valve insufficiency          725
# hypoglycemia                           710
# degenerative polyarthritis             710
# hepatitis C                            707
# gout                                   691
# arthritis                              657
# kidney failure acute                   645
# glaucoma                               644
# pancreatitis                           622
# neuropathy                             582
# neoplasm metastasis                    580
# asthma                                 441
# melanoma                               440
# pneumothorax                           390
# benign prostatic hypertrophy           380
# affect labile                          377
# hepatitis B                            355
# hypertension pulmonary                 350
# hyperbilirubinemia                     350
# thrombocytopaenia                      348
# Name: count, dtype: int64

# %%
disease_counts = train_data['disease_label'].value_counts()
print("Disease Distribution in Training Data:")
print(disease_counts)
# Out:
# Disease Distribution in Training Data:
# disease_label
# hypertensive disease                  1098
# biliary calculus                      1087
# hyperlipidemia                        1068
# colitis                               1003
# paroxysmal dyspnea                     990
# coronary arteriosclerosis              941
# osteomyelitis                          923
# infection                              913
# failure heart                          896
# gastritis                              875
# overload fluid                         862
# malignant neoplasms                    857
# hepatitis                              854
# delirium                               852
# deep vein thrombosis                   847
# manic disorder                         840
# dependence                             838
# stenosis aortic valve                  838
# effusion pericardial                   837
# tachycardia sinus                      837
# adenocarcinoma                         834
# epilepsy                               831
# schizophrenia                          828
# hyperglycemia                          821
# adhesion                               819
# obesity                                819
# obesity morbid                         817
# neutropenia                            817
# carcinoma breast                       814
# cirrhosis                              809
# pyelonephritis                         800
# infection urinary tract                798
# gastroenteritis                        796
# thrombus                               793
# sickle cell anemia                     790
# peripheral vascular disease            772
# fibroid tumor                          761
# ulcer peptic                           757
# chronic obstructive airway disease     728
# tricuspid valve insufficiency          725
# hypoglycemia                           710
# degenerative polyarthritis             710
# hepatitis C                            707
# gout                                   691
# arthritis                              657
# kidney failure acute                   645
# glaucoma                               644
# pancreatitis                           622
# neuropathy                             582
# neoplasm metastasis                    580
# asthma                                 441
# melanoma                               440
# pneumothorax                           390
# benign prostatic hypertrophy           380
# affect labile                          377
# hepatitis B                            355
# hypertension pulmonary                 350
# hyperbilirubinemia                     350
# thrombocytopaenia                      348
# Name: count, dtype: int64

# %% [markdown]
# # Load LLM

# %%
# Import the required classes
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Load BioBERT
model_name = "dmis-lab/biobert-base-cased-v1.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=59)  # Placeholder for `num_labels`

# GPU Check
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # LoRA (Low-Rank Adaptation)

# %%
# Configure LoRA for BioBERT
lora_config = LoraConfig(
    r=16,  # Low-rank adaptation rank
    lora_alpha=32,  # Scaling factor
    target_modules=["query", "value"],  # LoRA applied to attention layers
    lora_dropout=0.1,  # Dropout rate for regularization
    task_type="SEQ_CLS"  # Sequence classification task
)

model = get_peft_model(model, lora_config)
print("LoRA applied successfully to BioBERT!")
# Out:
# LoRA applied successfully to BioBERT!

# %% [markdown]
# # Tokenization function

# %%
# Tokenization function for the dataset
def tokenize_function(examples):
    # Tokenize the 'prompt' column
    tokenized_inputs = tokenizer(
        examples['prompt'],  # Input text (symptoms prompt)
        truncation=True,
        padding='max_length',
        max_length=256,  # Adjust as needed
        return_tensors="pt"
    )
    # Add 'labels' field (numeric targets)
    tokenized_inputs["labels"] = examples["target"]
    return tokenized_inputs

# Apply tokenization to the datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Set the dataset format for PyTorch
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
val_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/44164 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8810 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8846 [00:00<?, ? examples/s]

# %% [markdown]
# # Training Arguments

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    logging_strategy="steps",
    logging_steps=10,
    learning_rate=5e-5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=128,
    num_train_epochs = 7,
    weight_decay=0.001,
    logging_dir="./logs",
    save_strategy="epoch",
    save_total_limit=2,
    remove_unused_columns=False  # Disable column filtering
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset= val_dataset,
    tokenizer=tokenizer
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-11-6e21dec25147>:20: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset= val_dataset,
    tokenizer=tokenizer
)
# Out:
# <ipython-input-12-d09d09b8867b>:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# Train the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='9667' max='9667' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9667/9667 38:24, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.190900</td>
#       <td>1.989343</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.243500</td>
#       <td>1.029835</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.864900</td>
#       <td>0.622120</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.671800</td>
#       <td>0.452572</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.619600</td>
#       <td>0.364102</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.638900</td>
#       <td>0.329147</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.555000</td>
#       <td>0.316904</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9667, training_loss=1.177360484503141, metrics={'train_runtime': 2304.5064, 'train_samples_per_second': 134.149, 'train_steps_per_second': 4.195, 'total_flos': 4.100105192370586e+16, 'train_loss': 1.177360484503141, 'epoch': 7.0})

# %% [markdown]
# # Training and Validation Loss Graph

# %%
"""
import matplotlib.pyplot as plt

# Data from the table
epochs = [1, 2, 3, 4, 5, 6]
training_loss = [2.616900, 1.970200, 1.714200, 1.640900, 1.364900, 1.114800]
validation_loss = [2.713036, 1.945025, 1.528872, 1.351326, 1.194266, 1.159532]

# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(epochs, training_loss, label="Training Loss", marker="o")
plt.plot(epochs, validation_loss, label="Validation Loss", marker="o")

# Add labels, title, and legend
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Epochs")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
"""
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Data from the table\nepochs = [1, 2, 3, 4, 5, 6]\ntraining_loss = [2.616900, 1.970200, 1.714200, 1.640900, 1.364900, 1.114800]\nvalidation_loss = [2.713036, 1.945025, 1.528872, 1.351326, 1.194266, 1.159532]\n\n# Plot the graph\nplt.figure(figsize=(10, 6))\nplt.plot(epochs, training_loss, label="Training Loss", marker="o")\nplt.plot(epochs, validation_loss, label="Validation Loss", marker="o")\n\n# Add labels, title, and legend\nplt.xlabel("Epoch")\nplt.ylabel("Loss")\nplt.title("Training and Validation Loss Over Epochs")\nplt.legend()\nplt.grid(True)\n\n# Show the plot\nplt.show()\n'

# %% [markdown]
# # Evaluate the fine-tuned model directly

# %%
from datasets import Dataset

# Load the test dataset
test_file_path = '/content/drive/MyDrive/P2/T1/Dataset/combined/LLM-c-test.csv'
test_data = pd.read_csv(test_file_path)

# Add prompt column (if not already present)
test_data['prompt'] = test_data.apply(
    lambda row: f"Symptoms: {row['symptoms']}\nPredict the disease:",
    axis=1
)

# Convert to Hugging Face Dataset
test_dataset = Dataset.from_pandas(test_data)

# %%
import re

def predict_disease(prompt):
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=256).to("cuda")
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predicted_class_id = torch.argmax(logits, dim=-1).item()
        return id_to_label[predicted_class_id]  # Map numeric index back to text label

# Test Predictions
test_data['predicted_disease'] = test_data['prompt'].apply(predict_disease)

# Print Predictions
for index, row in test_data.iterrows():
    print(f"Prompt: {row['prompt']}")
    print(f"Predicted Disease: {row['predicted_disease']}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have orthopnea; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have distended abdomen; have cough.
# Predict the disease:
# Predicted Disease: pneumothorax
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have hematochezia; have fremitus; have pain.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have unresponsiveness; have asthenia; have haemorrhage; have hyperkalemia; have oliguria.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have lameness; have incoherent; have clammy skin; have claudication; have hypotension.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have hyponatremia; have burning sensation; have paresthesia.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have erythema; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have chill; have rhd positive.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokinesia; have patient non compliance; have pain.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have fremitus; have decreased stool caliber; have pain.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have decreased body weight; have hematochezia; have satiety early.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have hematuria; have urgency of micturition; have chill.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have wheezing; have chest tightness; have symptom aggravating factors; have non-productive cough; have productive cough; have distress respiratory; have cough.
# Predict the disease:
# Predicted Disease: asthma
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have ascites; have diarrhea; have pain.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have redness; have hypokinesia; have erythema; have hot flush.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have hemodynamically stable; have fever; have hematuria; have consciousness clear.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have sinus rhythm; have hyperkalemia; have angina pectoris; have sleepy.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have transaminitis; have spontaneous rupture of membranes; have distress respiratory; have tachypnea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have atypia; have hemodynamically stable; have distended abdomen; have pain.
# Predict the disease:
# Predicted Disease: arthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have cardiovascular finding; have scar tissue; have alcohol binge episode; have t wave inverted.
# Predict the disease:
# Predicted Disease: tachycardia sinus
# Prompt: Symptoms: Patient shows symptoms as follows: have breath sounds decreased; have heavy legs; have dyspnea on exertion; have cyanosis; have neck stiffness; have Stahli's line.
# Predict the disease:
# Predicted Disease: hypertension pulmonary
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have cicatrisation; have nausea; have impaired cognition; have bradycardia; have pain.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have scar tissue; have decreased stool caliber; have pain.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have asthenia; have polydypsia; have food intolerance; have pain; have numbness of hand.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have asthenia; have dizziness; have angina pectoris.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have sore to touch; have vomiting; have ascites.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have atypia; have asthenia; have hemodynamically stable; have distended abdomen; have pain.
# Predict the disease:
# Predicted Disease: arthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have haemorrhage; have vomiting; have disequilibrium.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have asthenia; have hemodynamically stable; have pain.
# Predict the disease:
# Predicted Disease: arthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypercapnia; have shortness of breath; have sputum purulent; have wheezing; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have cushingoid facies; have ascites; have pustule.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have headache; have apyrexial; have green sputum; have pain back.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have hemodynamically stable; have oliguria; have pain.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have fall; have ascites; have bleeding of vagina.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have lesion; have hematochezia; have egophony.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have giddy mood; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have redness; have patient non compliance; have emphysematous change; have pain; have hot flush.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have pruritus; have transaminitis; have distress respiratory.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have dizziness; have sweating increased.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have homelessness; have patient non compliance; have verbal auditory hallucinations; have hallucinations auditory; have hallucinations visual.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have pruritus; have ascites; have tumor cell invasion.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweat; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have hyponatremia; have suicidal; have diarrhea.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have ecchymosis; have non-productive cough; have hypotension.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypercapnia; have wheezing; have distress respiratory; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have nausea; have ascites; have cushingoid habitus.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have hematuria; have ascites; have emphysematous change.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have sputum purulent; have wheezing; have dyspnea; have distress respiratory; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dizziness; have angina pectoris; have fall; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have cicatrisation; have nausea; have vomiting; have impaired cognition.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have hypocalcemia result; have oliguria.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have worry; have verbally abusive behavior; have feeling suicidal.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nausea; have vomiting; have diarrhea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have sore to touch; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have lesion; have retropulsion; have difficulty.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have retch; have fever; have breath-holding spell.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have blanch; have decompensation; have verbal auditory hallucinations; have elation.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have green sputum; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have non-productive cough; have stiffness; have drowsiness; have pain.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have hyponatremia; have verbally abusive behavior.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have lesion; have egophony; have cicatrisation.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have verbal auditory hallucinations; have underweight.1; have irritable mood.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have ascites; have cushingoid habitus.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have projectile vomiting; have anorexia; have transaminitis.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have orthopnea; have hypotension; have dyspnea on exertion.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have non-productive cough; have productive cough; have distress respiratory.
# Predict the disease:
# Predicted Disease: asthma
# Prompt: Symptoms: Patient shows symptoms as follows: have intermenstrual heavy bleeding; have previous pregnancies 2; have abortion; have proteinemia.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have egophony; have decreased stool caliber; have pain.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have apyrexial; have pruritus; have diarrhea.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have hemodynamically stable; have hypotension; have diarrhea.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have hemodynamically stable; have haemorrhage; have diarrhea; have oliguria.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have sweat; have angina pectoris; have presence of q wave.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have unhappy; have dyspnea; have hypoxemia; have renal angle tenderness.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have hydropneumothorax; have slowing of urinary stream; have nausea and vomiting; have fatigability; have pain.
# Predict the disease:
# Predicted Disease: neuropathy
# Prompt: Symptoms: Patient shows symptoms as follows: have hypercapnia; have shortness of breath; have hypoxemia.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have lameness; have unconscious state; have claudication; have hypotension; have distress respiratory.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have chill.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have fatigue; have dyspnea; have hypokinesia; have systolic ejection murmur; have orthopnea.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have diarrhea; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have mental status changes; have orthopnea; have distress respiratory; have blackout.
# Predict the disease:
# Predicted Disease: benign prostatic hypertrophy
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have hematuria; have urgency of micturition; have diarrhea; have myalgia.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have dyspnea; have sinus rhythm; have sore to touch.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have ascites; have emphysematous change; have pain.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have lesion; have pruritus; have guaiac positive; have tumor cell invasion.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have snuffle; have hepatosplenomegaly; have pain.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have pruritus; have bleeding of vagina; have guaiac positive; have tumor cell invasion.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have hemodynamically stable; have nausea; have tenesmus; have chill.
# Predict the disease:
# Predicted Disease: colitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have decreased body weight; have fremitus.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have hyperkalemia; have rest pain.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have heavy feeling; have ascites; have ache; have hallucinations auditory; have macerated skin.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have stiffness; have nonsmoker; have drowsiness; have unsteady gait; have numbness of hand.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have gravida 0.
# Predict the disease:
# Predicted Disease: melanoma
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have swelling; have orthopnea; have distended abdomen; have weight gain.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have ascites; have cushingoid habitus.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokinesia; have sweat.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have inappropriate affect; have moan; have pain abdominal.
# Predict the disease:
# Predicted Disease: hepatitis B
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have vomiting; have diarrhea; have paraparesis; have mass in breast; have pain.
# Predict the disease:
# Predicted Disease: melanoma
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have ascites; have cushingoid habitus.
# Predict the disease:
# Predicted Disease: malignant neoplasms
# Prompt: Symptoms: Patient shows symptoms as follows: have monoclonal; have distress respiratory; have cough.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have pruritus; have bleeding of vagina; have guaiac positive; have tumor cell invasion.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have snuffle; have hepatosplenomegaly; have pain.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have immobile; have decreased body weight; have flatulence.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have previous pregnancies 2; have muscle hypotonia.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have fall; have distended abdomen; have guaiac positive.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have intoxication; have nausea; have disequilibrium; have guaiac positive.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have general discomfort; have non-productive cough; have food intolerance.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have distended abdomen; have ascites; have ache; have macerated skin.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have asterixis; have patient non compliance; have distended abdomen; have ascites; have ache.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sinus rhythm; have hyperkalemia; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have monocytosis; have ecchymosis; have fatigue; have fever; have haemorrhage; have posterior rhinorrhea.
# Predict the disease:
# Predicted Disease: thrombocytopaenia
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokalemia; have hypotension.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have yellow sputum; have inappropriate affect; have moan; have abdominal tenderness.
# Predict the disease:
# Predicted Disease: hepatitis B
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have cardiomegaly; have non-productive cough; have hypotension; have pain.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling hopeless; have extreme exhaustion; have patient non compliance; have enuresis.
# Predict the disease:
# Predicted Disease: affect labile
# Prompt: Symptoms: Patient shows symptoms as follows: have burning sensation; have estrogen use; have mass in breast; have paresthesia.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have previous pregnancies 2; have heartburn; have para 2.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have chill.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling strange; have decreased body weight; have cushingoid facies; have ascites; have estrogen use.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have sweat; have chest discomfort.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have nervousness; have apyrexial; have vomiting; have hunger; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have breech presentation; have para 1; have bradycardia.
# Predict the disease:
# Predicted Disease: hyperbilirubinemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have lesion; have sore to touch; have fall; have bleeding of vagina.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have angina pectoris; have vertigo; have syncope.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sinus rhythm; have sore to touch; have hyperkalemia; have rest pain.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have sore to touch; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have stool color yellow; have hypokinesia; have hypertonicity; have hemodynamically stable.
# Predict the disease:
# Predicted Disease: thrombus
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling hopeless; have decompensation; have elation.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have nausea; have myalgia; have breath-holding spell.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have asthenia; have hyperkalemia; have diarrhea; have oliguria.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have out of breath; have nausea; have paraparesis.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have hematuria; have vomiting; have myalgia; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have erythema; have difficulty; have mass in breast; have paresthesia.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have apyrexial; have green sputum; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have yellow sputum; have inappropriate affect; have abdominal tenderness; have projectile vomiting; have wheelchair bound.
# Predict the disease:
# Predicted Disease: hepatitis B
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have cardiomegaly; have non-productive cough; have hypotension; have pain.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have ascites.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have tremor; have lethargy; have muscle twitch.
# Predict the disease:
# Predicted Disease: epilepsy
# Prompt: Symptoms: Patient shows symptoms as follows: have suicidal; have verbal auditory hallucinations; have hallucinations auditory.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have abnormally hard consistency; have previous pregnancies 2; have hypotonic.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have sleepy; have weight gain.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have breech presentation; have para 1; have lung nodule.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have lethargy; have hyponatremia; have asthenia; have distress respiratory; have renal angle tenderness.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dizziness; have sweating increased.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have redness; have patient non compliance; have ascites; have erythema; have pain.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have weight gain.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea
# Prompt: Symptoms: Patient shows symptoms as follows: have hyponatremia; have withdraw; have verbally abusive behavior; have unsteady gait.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have hematochezia; have egophony; have decreased stool caliber.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have nausea; have bradycardia.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have headache; have breakthrough pain; have apyrexial; have green sputum.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have haemorrhage; have muscle hypotonia.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have overweight; have systolic murmur.
# Predict the disease:
# Predicted Disease: obesity
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have lesion; have unsteady gait; have paresthesia.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have diarrhea.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have chill; have feeling suicidal.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokalemia; have orthopnea; have hyperkalemia; have drowsiness; have sleepy.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have projectile vomiting; have pruritus; have chill.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokalemia; have orthopnea; have hyperkalemia; have distended abdomen; have drowsiness.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling hopeless; have heavy legs; have lethargy; have seizure.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have incoherent; have unconscious state; have clammy skin; have hypotension.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have urinary hesitation; have apyrexial; have sore to touch; have erythema.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have difficulty.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have unconscious state; have clammy skin; have claudication; have qt interval prolonged.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have hunger; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have stiffness; have food intolerance; have drowsiness; have pain.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokalemia; have swelling; have orthopnea; have hypotension.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have tremor; have aura; have wheelchair bound; have hemiplegia.
# Predict the disease:
# Predicted Disease: epilepsy
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have hallucinations visual; have para 1; have pain.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have fever; have apyrexial; have erythema; have decreased translucency.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have redness.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have vomiting; have paraparesis; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have mental status changes; have orthostasis; have night sweat; have dysarthria; have anorexia; have cachexia.
# Predict the disease:
# Predicted Disease: benign prostatic hypertrophy
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have ascites; have hallucinations auditory; have chill; have cough.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have cardiomegaly; have dyspnea; have hypotension; have pericardial friction rub.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have pain abdominal; have satiety early; have decreased stool caliber.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have swelling; have cardiomegaly; have hypotension; have pain.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have asthenia; have nausea; have syncope.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have tremor; have lethargy; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: epilepsy
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have unhappy; have out of breath; have labored breathing.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have nausea; have urgency of micturition; have vomiting; have myalgia; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have hypokinesia; have chest discomfort; have angina pectoris.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweat; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have mental status changes; have orthopnea; have night sweat; have dysarthria; have cachexia; have blackout.
# Predict the disease:
# Predicted Disease: benign prostatic hypertrophy
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have unhappy; have labored breathing.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have tremor; have intoxication; have lethargy; have seizure.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have vomiting; have ascites; have distress respiratory.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have sore to touch; have ascites; have pain.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have asterixis; have patient non compliance; have ache; have hallucinations auditory; have macerated skin.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have pain abdominal; have fever; have scleral icterus; have nausea.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have ascites.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have yellow sputum; have abdominal tenderness; have wheelchair bound; have poor feeding.
# Predict the disease:
# Predicted Disease: hepatitis B
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have nausea; have hunger; have hemiplegia; have gurgle.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokalemia; have swelling; have rale; have hyperkalemia; have sleepy.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling hopeless; have difficulty; have verbally abusive behavior; have hallucinations visual.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have distended abdomen; have paresthesia.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have systolic murmur; have pain.
# Predict the disease:
# Predicted Disease: stenosis aortic valve
# Prompt: Symptoms: Patient shows symptoms as follows: have mood depressed; have pustule.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have fall; have syncope.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have hematuria; have urgency of micturition; have diarrhea; have chill; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have dyspnea; have hypokinesia; have systolic ejection murmur; have pansystolic murmur.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have nausea; have chill; have pain.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have unresponsiveness; have asthenia; have hemodynamically stable; have haemorrhage.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have sweat; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have unconscious state; have lesion; have distended abdomen; have unsteady gait; have paresthesia.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have decreased body weight; have haemorrhage; have nausea; have sore to touch; have guaiac positive.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have heme positive; have dizziness; have sore to touch.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have hypertonicity; have sore to touch; have hypoalbuminemia.
# Predict the disease:
# Predicted Disease: thrombus
# Prompt: Symptoms: Patient shows symptoms as follows: have incoherent; have unresponsiveness; have unconscious state; have clammy skin; have distress respiratory.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have r wave feature; have overweight; have pain.
# Predict the disease:
# Predicted Disease: obesity
# Prompt: Symptoms: Patient shows symptoms as follows: have abscess bacterial; have pruritus; have diarrhea; have decreased translucency; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have chill.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have hyperkalemia; have hypotension; have sleepy; have weight gain.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have ecchymosis; have redness; have hypotension; have pain.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have lethargy; have mental status changes; have consciousness clear; have renal angle tenderness.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have retropulsion; have erythema; have difficulty; have paresthesia.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain abdominal; have pain chest; have hunger; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have agitation; have homelessness; have hallucinations auditory; have irritable mood; have hypersomnolence.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have unconscious state; have agitation; have lesion; have fall; have burning sensation.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have mediastinal shift; have nausea; have vomiting; have impaired cognition; have bradycardia.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have dizziness; have sweating increased.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have intoxication; have haemorrhage; have vomiting; have guaiac positive; have pain.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have sleeplessness; have asthenia; have hemodynamically stable; have general unsteadiness; have syncope; have pain.
# Predict the disease:
# Predicted Disease: arthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have hypertonicity; have pruritus; have vomiting.
# Predict the disease:
# Predicted Disease: thrombus
# Prompt: Symptoms: Patient shows symptoms as follows: have hemodynamically stable; have fever; have mental status changes; have consciousness clear; have renal angle tenderness.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have hyponatremia; have scleral icterus; have sore to touch; have myalgia.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have intoxication; have decreased body weight; have sore to touch; have vomiting.
# Predict the disease:
# Predicted Disease: gastritis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have sore to touch; have angina pectoris; have anorexia.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have feeling hopeless; have agitation; have muscle twitch; have rale.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have pain foot; have urinary hesitation; have apyrexial; have erythema; have difficulty passing urine.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain; have hot flush.
# Predict the disease:
# Predicted Disease: gout
# Prompt: Symptoms: Patient shows symptoms as follows: have sputum purulent; have cardiomegaly; have dyspnea; have hypotension.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have polymyalgia; have pain chest; have out of breath; have hemiplegia.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have angina pectoris; have dyspnea on exertion; have pressure chest.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have ecchymosis; have r wave feature; have mood depressed; have overweight.
# Predict the disease:
# Predicted Disease: obesity
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have urinary hesitation; have fever; have prostate tender.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have projectile vomiting; have vomiting; have ascites; have tachypnea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have abnormally hard consistency; have heartburn; have hypotonic; have proteinemia.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have symptom aggravating factors; have non-productive cough; have productive cough; have pleuritic pain; have cough.
# Predict the disease:
# Predicted Disease: asthma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain chest; have hypokinesia; have angina pectoris; have sweating increased.
# Predict the disease:
# Predicted Disease: coronary arteriosclerosis
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have projectile vomiting; have anorexia; have transaminitis; have chill.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have apyrexial; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have abnormally hard consistency; have heartburn; have proteinemia; have muscle hypotonia.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have vomiting; have anorexia; have chill; have distress respiratory; have tachypnea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain chest; have asthenia; have fall.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have diarrhea.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have atypia; have mass of body structure; have pain neck; have thicken; have metastatic lesion; have lung nodule.
# Predict the disease:
# Predicted Disease: neoplasm metastasis
# Prompt: Symptoms: Patient shows symptoms as follows: have worry; have homelessness; have patient non compliance; have hallucinations visual; have hypersomnolence.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have scar tissue; have constipation; have mass of body structure; have pain abdominal.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have orthopnea; have hypotension.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have bedridden; have hallucinations visual.
# Predict the disease:
# Predicted Disease: affect labile
# Prompt: Symptoms: Patient shows symptoms as follows: have hemodynamically stable; have hypotension; have diarrhea; have hypocalcemia result; have oliguria.
# Predict the disease:
# Predicted Disease: kidney failure acute
# ...
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have fever; have drowsiness.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have hemodynamically stable; have fall; have ascites; have tumor cell invasion.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have diarrhea; have decreased translucency; have hepatosplenomegaly; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have general discomfort; have asthenia; have non-productive cough; have stiffness; have unsteady gait.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have apyrexial; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have chill.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have splenomegaly; have fall; have distended abdomen; have ascites.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have lameness; have unresponsiveness; have unconscious state; have distress respiratory; have polyuria.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have pain abdominal; have apyrexial; have nausea; have rigor - temperature-associated observation.
# Predict the disease:
# Predicted Disease: pancreatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have nausea; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain abdominal; have mediastinal shift; have vomiting; have impaired cognition; have pain.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have asthenia; have hydropneumothorax; have numbness; have slowing of urinary stream; have tenesmus; have superimposition.
# Predict the disease:
# Predicted Disease: neuropathy
# Prompt: Symptoms: Patient shows symptoms as follows: have dizziness; have chest discomfort; have photopsia.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have angina pectoris; have sweating increased; have hemiplegia.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have constipation; have mass of body structure; have decreased body weight; have satiety early.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have hypokinesia; have hemodynamically stable; have pruritus; have anorexia; have hypoalbuminemia.
# Predict the disease:
# Predicted Disease: thrombus
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have headache; have breakthrough pain; have snuffle; have pain.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have hematocrit decreased; have labored breathing; have cough.
# Predict the disease:
# Predicted Disease: obesity morbid
# Prompt: Symptoms: Patient shows symptoms as follows: have headache; have breakthrough pain; have pain chest.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have monoclonal; have snuffle; have rhd positive.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have patient non compliance; have verbal auditory hallucinations; have hallucinations auditory; have underweight.1.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have lesion; have decreased stool caliber.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have hematuria; have urgency of micturition; have vomiting; have diarrhea; have myalgia.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have constipation; have mass of body structure; have lesion.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have pruritus; have tachypnea.
# Predict the disease:
# Predicted Disease: hepatitis
# Prompt: Symptoms: Patient shows symptoms as follows: have suicidal; have verbal auditory hallucinations; have hallucinations auditory.
# Predict the disease:
# Predicted Disease: manic disorder
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have hypotension; have hypocalcemia result.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have pain foot; have redness; have erythema; have prostate tender; have pain.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have headache; have pain chest; have hepatosplenomegaly.
# Predict the disease:
# Predicted Disease: sickle cell anemia
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have decreased body weight; have hyponatremia; have fever.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have scar tissue; have mass of body structure; have fremitus; have pain.
# Predict the disease:
# Predicted Disease: adenocarcinoma
# Prompt: Symptoms: Patient shows symptoms as follows: have intoxication; have cardiomegaly; have dyspnea; have hypotension; have facial paresis.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have hypercapnia; have agitation; have cardiovascular event; have soft tissue swelling.
# Predict the disease:
# Predicted Disease: pneumothorax
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have unconscious state; have distended abdomen; have unsteady gait.
# Predict the disease:
# Predicted Disease: glaucoma
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have pain abdominal; have sore to touch; have cushingoid habitus; have diarrhea.
# Predict the disease:
# Predicted Disease: biliary calculus
# Prompt: Symptoms: Patient shows symptoms as follows: have hypotension; have pericardial friction rub; have oliguria; have blackout.
# Predict the disease:
# Predicted Disease: effusion pericardial
# Prompt: Symptoms: Patient shows symptoms as follows: have left atrial hypertrophy; have cardiovascular event; have vomiting; have sweating increased.
# Predict the disease:
# Predicted Disease: tachycardia sinus
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have lesion; have burning sensation; have paresthesia.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have orthopnea; have hypotension; have sleepy.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have asthenia; have distress respiratory; have difficulty passing urine; have renal angle tenderness.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have mass of body structure; have pain neck; have thicken; have food intolerance; have tumor cell invasion.
# Predict the disease:
# Predicted Disease: neoplasm metastasis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have orthopnea; have hypotension; have drowsiness; have weight gain.
# Predict the disease:
# Predicted Disease: overload fluid
# Prompt: Symptoms: Patient shows symptoms as follows: have non-productive cough; have stiffness; have nonsmoker; have polydypsia.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have sinus rhythm; have angina pectoris; have labored breathing.
# Predict the disease:
# Predicted Disease: peripheral vascular disease
# Prompt: Symptoms: Patient shows symptoms as follows: have stool color yellow; have hemodynamically stable; have sore to touch; have facial paresis.
# Predict the disease:
# Predicted Disease: thrombus
# Prompt: Symptoms: Patient shows symptoms as follows: have out of breath; have nervousness; have apyrexial; have vomiting.
# Predict the disease:
# Predicted Disease: ulcer peptic
# Prompt: Symptoms: Patient shows symptoms as follows: have pruritus; have hepatosplenomegaly; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have decreased body weight; have retch.
# Predict the disease:
# Predicted Disease: gastroenteritis
# Prompt: Symptoms: Patient shows symptoms as follows: have haemorrhage; have heartburn; have proteinemia.
# Predict the disease:
# Predicted Disease: fibroid tumor
# Prompt: Symptoms: Patient shows symptoms as follows: have mental status changes; have orthostasis; have night sweat; have anorexia; have distress respiratory.
# Predict the disease:
# Predicted Disease: benign prostatic hypertrophy
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have swelling; have general unsteadiness; have syncope.
# Predict the disease:
# Predicted Disease: arthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have worry; have homelessness; have verbal auditory hallucinations; have underweight; have hypersomnolence.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have patient non compliance; have hypoxemia; have distress respiratory.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have mood depressed; have sore to touch; have cushingoid habitus.
# Predict the disease:
# Predicted Disease: hyperglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have tremor; have muscle twitch; have homelessness.
# Predict the disease:
# Predicted Disease: dependence
# Prompt: Symptoms: Patient shows symptoms as follows: have fever; have suicidal; have verbally abusive behavior; have sleepy.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have dyspnea; have cough.
# Predict the disease:
# Predicted Disease: chronic obstructive airway disease
# Prompt: Symptoms: Patient shows symptoms as follows: have unresponsiveness; have worry; have fever; have diarrhea.
# Predict the disease:
# Predicted Disease: delirium
# Prompt: Symptoms: Patient shows symptoms as follows: have splenomegaly; have sore to touch; have fall; have bleeding of vagina; have guaiac positive.
# Predict the disease:
# Predicted Disease: cirrhosis
# Prompt: Symptoms: Patient shows symptoms as follows: have worry; have underweight; have underweight.1; have hallucinations visual.
# Predict the disease:
# Predicted Disease: schizophrenia
# Prompt: Symptoms: Patient shows symptoms as follows: have drowsiness; have unsteady gait; have pain; have numbness of hand.
# Predict the disease:
# Predicted Disease: degenerative polyarthritis
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain abdominal; have vomiting; have impaired cognition.
# Predict the disease:
# Predicted Disease: tricuspid valve insufficiency
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have hypocalcemia result; have chill; have oliguria.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have jugular venous distention; have pansystolic murmur; have hypotension.
# Predict the disease:
# Predicted Disease: failure heart
# Prompt: Symptoms: Patient shows symptoms as follows: have ache; have hallucinations auditory; have macerated skin; have chill.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have immobile; have breech presentation; have vomiting; have pain.
# Predict the disease:
# Predicted Disease: adhesion
# Prompt: Symptoms: Patient shows symptoms as follows: have hypocalcemia result; have monoclonal; have oliguria; have rhd positive.
# Predict the disease:
# Predicted Disease: neutropenia
# Prompt: Symptoms: Patient shows symptoms as follows: have palpitation; have asthenia; have sweat; have pressure chest.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have lameness; have hypothermia, natural; have unresponsiveness; have qt interval prolonged; have distress respiratory.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have swelling; have cardiomegaly; have clonus; have hypotension; have erythema.
# Predict the disease:
# Predicted Disease: deep vein thrombosis
# Prompt: Symptoms: Patient shows symptoms as follows: have urinary hesitation; have abscess bacterial; have fever; have erythema; have pain.
# Predict the disease:
# Predicted Disease: osteomyelitis
# Prompt: Symptoms: Patient shows symptoms as follows: have pain abdominal; have fever; have vomiting.
# Predict the disease:
# Predicted Disease: pyelonephritis
# Prompt: Symptoms: Patient shows symptoms as follows: have lesion; have burning sensation; have estrogen use; have formication; have paresthesia.
# Predict the disease:
# Predicted Disease: carcinoma breast
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have vomiting; have sweating increased; have pressure chest.
# Predict the disease:
# Predicted Disease: hypertensive disease
# Prompt: Symptoms: Patient shows symptoms as follows: have dysuria; have asthenia; have consciousness clear; have distress respiratory; have renal angle tenderness.
# Predict the disease:
# Predicted Disease: infection urinary tract
# Prompt: Symptoms: Patient shows symptoms as follows: have heavy feeling; have patient non compliance; have ascites; have hallucinations auditory; have macerated skin.
# Predict the disease:
# Predicted Disease: hepatitis C
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have pain chest; have sweat; have angina pectoris.
# Predict the disease:
# Predicted Disease: hyperlipidemia
# Prompt: Symptoms: Patient shows symptoms as follows: have awakening early; have asthenia; have numbness; have tenesmus.
# Predict the disease:
# Predicted Disease: neuropathy
# Prompt: Symptoms: Patient shows symptoms as follows: have hypothermia, natural; have hemodynamically stable; have haemorrhage; have hyperkalemia; have hypocalcemia result; have oliguria.
# Predict the disease:
# Predicted Disease: kidney failure acute
# Prompt: Symptoms: Patient shows symptoms as follows: have incoherent; have unconscious state; have clammy skin; have qt interval prolonged; have distress respiratory.
# Predict the disease:
# Predicted Disease: hypoglycemia
# Prompt: Symptoms: Patient shows symptoms as follows: have apyrexial; have decreased translucency; have chill; have hepatosplenomegaly; have cough.
# Predict the disease:
# Predicted Disease: infection
# Prompt: Symptoms: Patient shows symptoms as follows: have wheezing; have distress respiratory; have cough.
# Predict the disease:
# Predicted Disease: asthma
# Prompt: Symptoms: Patient shows symptoms as follows: have shortness of breath; have palpitation; have pain chest; have sweating increased; have cough.
# Predict the disease:
# Predicted Disease: paroxysmal dyspnea

# %% [markdown]
# # Save fine-tuned Model

# %%
"""
# Save the fine-tuned model
model.save_pretrained('/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt')
tokenizer.save_pretrained('/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt')
print("Fine-tuned BioGPT model and tokenizer saved successfully!")
"""
# Out:
# '\n# Save the fine-tuned model\nmodel.save_pretrained(\'/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt\')\ntokenizer.save_pretrained(\'/content/drive/MyDrive/P2/LLM/fine_tuned_biogpt\')\nprint("Fine-tuned BioGPT model and tokenizer saved successfully!")\n'

# %% [markdown]
# # Generate Classification Report

# %%
from sklearn.metrics import classification_report
import pandas as pd

# Assume `test_data` is your test dataset after generating predictions
# The test_data dataframe should already have columns: 'Label' (true labels) and 'Predicted' (model predictions)

# True labels and predicted labels
true_labels = test_data['disease_label']
predicted_labels = test_data['predicted_disease']

# Generate classification report
report = classification_report(true_labels, predicted_labels, output_dict=False)
print(report)

# Save classification report to a file
report_dict = classification_report(true_labels, predicted_labels, output_dict=True)
pd.DataFrame(report_dict).transpose().to_csv('/content/drive/MyDrive/P2/T1/Dataset/combined/LLM/BioBERT-c-class.csv', index=True)
print("Classification report saved to '/content/drive/MyDrive/P2/T1/Dataset/combined/LLM/BioBERT-c-class.csv'")
# Out:
#                                     precision    recall  f1-score   support
#
#                     adenocarcinoma       0.96      0.94      0.95       171
#                           adhesion       0.97      0.93      0.95       168
#                      affect labile       1.00      0.91      0.95        79
#                          arthritis       0.97      0.92      0.94       131
#                             asthma       0.83      0.98      0.90        83
#       benign prostatic hypertrophy       0.95      0.91      0.93        79
#                   biliary calculus       0.85      0.85      0.85       194
#                   carcinoma breast       0.97      0.97      0.97       170
# chronic obstructive airway disease       0.86      0.90      0.88       139
#                          cirrhosis       0.99      0.87      0.93       178
#                            colitis       0.95      0.84      0.89       178
#          coronary arteriosclerosis       0.71      0.79      0.75       162
#               deep vein thrombosis       0.95      0.96      0.96       168
#         degenerative polyarthritis       1.00      0.99      0.99       151
#                           delirium       0.95      0.89      0.92       178
#                         dependence       0.93      0.99      0.96       167
#               effusion pericardial       0.95      0.95      0.95       169
#                           epilepsy       0.87      0.98      0.92       172
#                      failure heart       0.89      0.93      0.91       163
#                      fibroid tumor       1.00      0.99      0.99       163
#                          gastritis       1.00      0.88      0.93       171
#                    gastroenteritis       0.95      0.91      0.93       164
#                           glaucoma       1.00      0.91      0.95       131
#                               gout       0.93      0.96      0.95       137
#                          hepatitis       0.94      0.89      0.91       183
#                        hepatitis B       0.99      0.93      0.96        75
#                        hepatitis C       1.00      0.98      0.99       151
#                 hyperbilirubinemia       1.00      0.87      0.93        75
#                      hyperglycemia       0.99      0.91      0.95       173
#                     hyperlipidemia       0.82      0.73      0.77       215
#             hypertension pulmonary       1.00      0.99      0.99        75
#               hypertensive disease       0.71      0.84      0.77       210
#                       hypoglycemia       1.00      0.99      0.99       152
#                          infection       0.84      0.95      0.89       176
#            infection urinary tract       1.00      0.95      0.98       167
#               kidney failure acute       0.96      0.89      0.93       139
#               malignant neoplasms        0.91      0.95      0.93       161
#                     manic disorder       0.85      0.96      0.90       171
#                           melanoma       1.00      0.79      0.88        80
#                neoplasm metastasis       1.00      1.00      1.00       124
#                         neuropathy       1.00      0.95      0.98       124
#                        neutropenia       0.94      0.94      0.94       176
#                            obesity       0.99      0.96      0.98       164
#                     obesity morbid       0.94      0.94      0.94       172
#                      osteomyelitis       0.95      0.95      0.95       172
#                     overload fluid       0.94      0.92      0.93       171
#                       pancreatitis       0.66      0.76      0.71       100
#                 paroxysmal dyspnea       0.87      0.83      0.85       196
#        peripheral vascular disease       0.97      0.94      0.95       158
#                       pneumothorax       0.84      0.87      0.85        82
#                     pyelonephritis       0.66      0.91      0.77       157
#                      schizophrenia       0.98      0.91      0.94       169
#                 sickle cell anemia       0.80      1.00      0.89       153
#              stenosis aortic valve       0.91      0.97      0.94       162
#                  tachycardia sinus       0.98      0.87      0.92       171
#                  thrombocytopaenia       1.00      0.99      0.99        74
#                           thrombus       0.97      0.91      0.94       160
#      tricuspid valve insufficiency       0.91      0.94      0.92       131
#                       ulcer peptic       1.00      0.95      0.97       161
#
#                           accuracy                           0.92      8846
#                          macro avg       0.93      0.92      0.92      8846
#                       weighted avg       0.92      0.92      0.92      8846
#
# Classification report saved to '/content/drive/MyDrive/P2/T1/Dataset/combined/LLM/BioBERT-c-class.csv'

# %%
"""
output_path = '/content/drive/MyDrive/P2/LLM/2BioBERT_Predictions.csv'
test_data.to_csv(output_path, index=False)
print(f"Predictions saved to: {output_path}")
"""
# Out:
# '\noutput_path = \'/content/drive/MyDrive/P2/LLM/2BioBERT_Predictions.csv\'\ntest_data.to_csv(output_path, index=False)\nprint(f"Predictions saved to: {output_path}")\n'
